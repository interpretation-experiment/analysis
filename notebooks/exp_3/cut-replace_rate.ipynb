# %% [markdown]
# # Cut-replace rate: how much is a sentence cut vs. replaced

# %% [markdown]
# ## 1 Setup

# %% [markdown]
# Flags

# %%
SAVE_FIGURES = False

# %% [markdown]
# Setup the database

# %%
import os, sys
sys.path.insert(1, os.path.abspath('../..'))
import analysis

FIG = os.path.join(os.path.abspath(os.path.curdir), '{}.png')
DB_NAME = 'spreadr_' + os.path.split(os.path.abspath(os.path.curdir))[1]
analysis.setup(DB_NAME)
print('Database:', DB_NAME)
# Out:
# Database: spreadr_exp_3

# %% [markdown]
# Imports for the analysis

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
import numpy as np
from pandas import DataFrame
from scipy.stats import linregress
import seaborn as sb

from gists.models import Sentence, Tree

from analysis.utils import grouper, memoized, mpl_palette

# %% [markdown]
# ## 2 Cut-replace rate per tree

# %% [markdown]
# First build our data

# %%
trees = Tree.objects.experiment.all()
data = []
order = []
for tree in trees:
    root = tree.root
    order.append({'tree id': tree.id,
                  'root_content_words_count': len(root.content_words)})
    for sentence in tree.sentences.kept.all():
        data.append({'tree id': tree.id,
                     'sentence id': sentence.id,
                     'length': len(sentence.content_words),
                     'length / len(root)': len(sentence.content_words) / len(root.content_words),
                     'diff from root': root.uc_distance(sentence)
                    })
data = DataFrame(data)
root_order = DataFrame(order).sort_values(['root_content_words_count', 'tree id'])

# %% [markdown]
# For each tree, plot the length of a sentence (number of content words relative to number content words of its tree root, so immune so minor changes) as a function of the difference from its tree root (difference taken as distance between bags of content words, so unordered).
#
# On each plot there are 3 interesting spots:
# * a sentence in the upper-left is very close to the root, both in length and content;
# * a sentence in the upper-right is very different to the root, but about the same length; so it's different from its root, because many words are replaced;
# * a sentence in the lower-right is very different to the root, and a lot shorter too; so it's different mainly because it's been croppped a lot.
#
# So, the steeper the slope (downwards), the more a tree has its sentences cut, i.e. words removed. The flatter the slope, the more it has its sentences transformed, i.e. words replaced.
#
# Plots are **ordered by number of content words in the root of the tree**, which correlates a lot to the slope.

# %%
g = sb.lmplot(data=data,
              y='length / len(root)', x='diff from root',
              col='tree id', col_wrap=7, size=1.5,
              col_order=root_order['tree id'])
g.set(xlim=(-0.1, 1.1), ylim=(-0.1, 1.5))
if SAVE_FIGURES:
    g.savefig(FIG.format('cut-replace_rate'), dpi=300)

# %% [markdown]
# Most trees seem to give flat or negative slope (i.e. the shorter the sentence, the more different it is from its root).

# %% [markdown]
# ## 3 Cut-replace rate ~ number of initial content words, which seem closely related

# %% [markdown]
# First build our data

# %%
slope_content = []
for tree in Tree.objects.experiment.all():
    tree_data = data[data['tree id'] == tree.id]
    slope, intercept, r_value, p_value, std_err = linregress(tree_data['diff from root'],
                                                             tree_data['length / len(root)'])
    slope_content.append({'tree id': tree.id,
                          'root content words count': len(tree.root.content_words),
                          'slope': slope})
slope_content = DataFrame(slope_content)

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 4))
sb.regplot(ax=ax, data=slope_content,
           x='root content words count', y='slope',
           x_jitter=.2, robust=True)
ax.set_title('Cut-replace rate ~ number of root content words')
if SAVE_FIGURES:
    fig.savefig(FIG.format('scatter_cut-replace_content'), dpi=300)

# %% [markdown]
# In the graph above, a more negative 'slope' value means more shortening and less replacement (and vice-versa).
#
# It's decreasing: more content words means (more or less linearly) more cutting and less replacement when you transform. Less content words means you do more replacing. It makes sense: if a sentence is very long, you're likely to remember the beginning, or the end, and forget the rest. If a sentence is very short, you're likely to remember the gist and replace its words.

# %% [markdown]
# There are a few outliers:

# %%
outliers = slope_content\
    [(slope_content['slope'] <= -.8) | (slope_content['slope'] >= .5)]\
    .sort_values(by=['slope'])
outliers
# Out:
#     root content words count     slope  tree id
# 22                        33 -1.152602       26
# 46                        34 -1.079310       53
# 24                        22 -1.073625       28
# 47                        33 -1.003668       54
# 18                        12 -0.977306       22
# 23                        24 -0.962783       27
# 26                         9 -0.899730       33
# 4                          9 -0.893929        8
# 16                        15 -0.892833       20
# 33                        13 -0.859012       40
# 35                        12 -0.850597       42
# 2                         11 -0.838955        6
# 5                         10 -0.819392        9
# 49                        24 -0.815273       56
# 12                        12 -0.808750       16

# %% [markdown]
# ## 4 A few more details

# %% [markdown]
# Here are the root sentences for all trees, for a detailed look:

# %%
for tree in Tree.objects.experiment.all():
    print('Tree #{}'.format(tree.id))
    print('--------')
    print(tree.root.text)
    print()
# Out:
# Tree #4
# --------
# At Dover, the finale of the bailiffs' convention. Their duties, said a speaker, are "delicate, dangerous, and insufficiently compensated."
#
# Tree #5
# --------
# Three bears driven down from the heights of the Pyrenees by snow have been decimating the sheep of the valley.
#
# Tree #6
# --------
# A dozen hawkers who had been announcing news of a nonexistent anarchist bombing at King's Cross have been arrested.
#
# Tree #7
# --------
# Due to their ardour during audits and polls, some congregants and a voter have been sentenced, in Derby and Nottingham.
#
# Tree #8
# --------
# The charge of embezzlement against the management of the Canterbury artillery amounts to nothing, according to the manager's inquiry.
#
# Tree #9
# --------
# Clash in the street between the municipal powers of Morley, Leeds, and the party of the opposition. Two constables were injured.
#
# Tree #10
# --------
# The May Day celebration in Calais was noisy, but not a hint of violence gave the slightest cause for police intervention.
#
# Tree #11
# --------
# Hanging on to the door, a traveller a tad overweight caused his carriage to topple, in Bromley, and fractured his skull.
#
# Tree #12
# --------
# In a cafe on Newark Street, Ward, Lenoir, and Hughes exchanged a few bullets regarding their wives, who were not present.
#
# Tree #13
# --------
# Ten years' hard labour were given Scott by the court in Leigh. The adolescent killed a traveller who employed him as guide.
#
# Tree #14
# --------
# In Bradford, the courts and the bar have reestablished contact with the prison, now that the typhus outbreak there has been curbed.
#
# Tree #15
# --------
# Because of his poster opposing the strikebreakers, the students of Preston secondary school hissed their teacher, M. Griffith, an aide to the mayor.
#
# Tree #16
# --------
# The recalled mayor of Coventry, his wife, and a member of the municipal council have been sentenced to prison for strike-related offences.
#
# Tree #17
# --------
# There was a gas explosion at the home of Bennett, in Cardiff. He was injured. His mother-in-law's hair caught on fire. The ceiling caved in.
#
# Tree #18
# --------
# An unidentified maker of paste jewels from the third district was fishing in a boat with his wife at Maldon. She fell. He dived. Both gone.
#
# Tree #19
# --------
# Because an automobile ran over his dog, a peasant from Bingham shot at another automobile. He got a year in jail, suspended.
#
# Tree #20
# --------
# 'Ouch!' cried the cunning oyster eater, 'A pearl!' Someone at the next table bought it for 100 pounds. It had cost 30 pence at the dime store.
#
# Tree #21
# --------
# Eugene Smith, of Ellsworth, near Bangor, entertained at his home Mrs Atwood. Eugene Taylor came to fetch her. They killed him. Love.
#
# Tree #22
# --------
# Finding his daughter, 19, insufficiently austere, Davies, watchmaker of Halifax, killed her. It is true that he has eleven children left.
#
# Tree #23
# --------
# In political disagreements, M. Kelly, journalist, and M. Shaw, MP, had called one another "thief" and "liar." They have reconciled.
#
# Tree #24
# --------
# Women suckling their infants argued the workers' cause to the director of the streetcar lines in Portland. He was unmoved.
#
# Tree #25
# --------
# Evans, of Dunkirk, fired three times at his wife. Since he missed every shot, he decided to aim at his mother-in-law, and connected.
#
# Tree #26
# --------
# Nancy is having an affair with her married college professor. Nancy recently became pregnant with the professor's child. The professor promised Nancy that he would leave his wife, but since Nancy told him she was pregnant, the professor refused to see her. So Nancy told the professor's wife about the affair. The professor's wife was so upset that she left the professor.
#
# Tree #27
# --------
# One morning, Sophie's alarm clock broke and she overslept. When she woke up, she realized that she was late for an important lecture. She got dressed as quickly as she could, left the house and ran to the lecture theatre. When she got there, the lecture theatre was empty. Sophie had missed the lecture.
#
# Tree #28
# --------
# It was half past seven on a fine July evening when Father Malone knocked at the front door of Sir John Tribe’s London house. He had hurried round from the Church where he had been saying Mass, so that he would not be late for dinner.
#
# Tree #32
# --------
# Reverend Powell, of Stamford, near Peterborough, whom a pitiless husband perforated Wednesday with two rifle shots, died last night.
#
# Tree #33
# --------
# A complaint was sworn by the Persian physician Ali Khan against a compatriot who had stolen from him a tiara.
#
# Tree #34
# --------
# In the second district, 27 violations have been charged in three days against cabdrivers who demanded excessive tips up front.
#
# Tree #35
# --------
# The Finance Minister has recommended to tax collectors in Gloucester that they be lenient with taxpayers adversely affected by strikes.
#
# Tree #36
# --------
# A criminal virago, Miss Fisher, was sentenced by the Liverpool court to 10 years' hard labour, while her lover got five.
#
# Tree #37
# --------
# The fever, of military origin, that is raging in Lincoln, Nebraska, is getting worse and spreading. Preventative measures have been taken.
#
# Tree #38
# --------
# A dishwasher from Bristol, Vital Gray, who had just come back from Lourdes cured forever of tuberculosis, died Sunday by mistake.
#
# Tree #39
# --------
# M. Webb denied to the commission that the new tax plan was a scheme to make the budget's ends meet.
#
# Tree #40
# --------
# Despite a 20-year penitentiary sentence, in his absence, M. Patel, a Glasgow architect, lived quietly in Plymouth. He was arrested there.
#
# Tree #41
# --------
# On the bowling lawn a stroke levelled M. Owen, 75, of Bath. While his ball was still rolling he was no more.
#
# Tree #42
# --------
# Despondent owing to the bankruptcy of one of his debtors, M. Arturo Grimaldi, merchant of Bizerte, killed himself with a hunting rifle.
#
# Tree #43
# --------
# A thunderstorm interrupted the celebration in Orleans in honour of Joan of Arc and the 477th anniversary of the defeat of the English.
#
# Tree #44
# --------
# David, of the 8th Colonial Regiment, Hereford, who incited inmates to riot in the correctional barracks, has been given 60 days in jail.
#
# Tree #45
# --------
# Mrs Wilson, of Ealing, failed to reckon with the ardour of Collins, the laundry's owner. He fished the desperate laundress from the Thames.
#
# Tree #46
# --------
# The photographer Josh Brown could not get over the death of his wife. He killed himself in York.
#
# Tree #47
# --------
# "If my candidate loses, I will kill myself," M. Carter, of Norwich, Norfolk, had declared. He killed himself.
#
# Tree #48
# --------
# Burning with electoral fervour, persons attending a speech by M. Lewis in Salisbury got into a fight. Several were injured, one seriously.
#
# Tree #49
# --------
# On Parliament Square, a heated group of voters attempted to roast an effigy of M. Morris, the losing candidate. They were dispersed.
#
# Tree #50
# --------
# Again and again Mrs Campbell, of Cambridge, was prevented from hanging herself from her window bolt. Exasperated, she fled across the fields.
#
# Tree #51
# --------
# Furious that someone swiped his catch, M. Mills, a fisherman of Falmouth, Cornwall, nearly killed the seafood fancier.
#
# Tree #52
# --------
# The city council of Wells voted in favour of an eight-hour day for the police force. Its decision was vetoed by the prefect.
#
# Tree #53
# --------
# Nancy enjoys swimming. Nancy was going to the swimming pool but got lost, so she asked an old man waiting at a bus stop for directions. The old man could not give her directions. A bus arrived at the bus stop and the old man asked the driver for directions. The driver gave Nancy directions to the swimming pool, so Nancy was able to go swimming.
#
# Tree #54
# --------
# The weather in Colorado gets hot and dry in the summer. This removes moisture from the soil and dries out the plants that grow there. The dry vegetation catches fire easily, leading to frequent forest fires. These fires release smoke containing carbon monoxide into the atmosphere. This smoke contributes to global warming, increasing temperatures further.
#
# Tree #55
# --------
# Sir John, Father Malone, and Mrs Tribe all went in to dinner, and the butler at once served them with apple pie.
#
# Tree #56
# --------
# When they were all talking and laughing quite cheerfully, Miss Weaver suddenly gave a terrific shriek and fell forward across the table with a bullet wound through her head. When the others reached her, they found that she was dead, and Sir John at once plucked the blood stained knife from her heart.

# %% [markdown]
# And the outliers' content words:

# %%
for tree in Tree.objects.filter(pk__in=outliers['tree id']):
    print('Tree #{}'.format(tree.id))
    print('--------')
    for s in tree.sentences.kept.all():
        print(s.content_words)
    print()
# Out:
# Tree #6
# --------
# ('dozen', 'terrorists', 'arrested', 'king', "'s", 'cross', 'exploding', 'terrorist', 'bomb')
# ('incident', 'hacker')
# ('dozen', 'hawkers', 'fake', 'news', 'bombings', 'kings', 'cross', 'arrested')
# ('dozen', 'hawkers', 'fake', 'news', 'bombings', 'kings', 'cross', 'arrested')
# ('dozen', 'hackers', 'announced', 'bombing', 'released')
# ('dozen', 'hawkers', 'fake', 'news', 'bombings', 'kings', 'cross', 'arrested')
# ('dozen', 'hawkers', 'new', 'kings', 'cross', 'arrested')
# ('incident', 'hacker')
# ('bomber', 'kings', 'cross', 'arrested')
# ('dozen', 'hawkers', 'fake', 'news', 'bombings', 'kings', 'cross', 'arrested')
# ('dozen', 'hawkers', 'new', 'kings', 'cross', 'arrested')
# ('dozen', 'hawker', 'new', 'kings', 'cross', 'arrested')
# ('dozen', 'hawker', 'new', 'kings', 'cross', 'arrested')
# ('dozen', 'hawkers', 'fake', 'news', 'bombings', 'kings', 'cross', 'arrested')
# ('bomber', 'kings', 'cross', 'arrested')
# ('dozen', 'hawkers', 'arrested', 'fake', 'news', 'bombings', 'kings', 'cross', 'arrested')
# ('dozen', 'hawkers', 'arrested', 'fake', 'news', 'bombings', 'king', 'cross', 'arrested')
# ('bomber', 'kings', 'cross', 'arrested')
# ('incident', 'hacker')
# ('dozen', 'hackers', 'announced', 'bombing', 'released')
# ('dozen', 'hawker', 'new', 'kings', 'cross', 'arrested')
# ('incident', 'hacker')
# ('dozen', 'terrorists', 'arrested', 'kings', 'cross', 'exploding', 'terrorist', 'bomb')
# ('bombing', 'kings', 'cross', 'arrested')
# ('incident', 'hacker', 'announced', 'non', 'existent', 'bombing', 'arrested')
# ('dozen', 'hackers', 'announced', 'news', 'bombing', 'released')
# ('incident', 'hackers', 'announced', 'non', 'existent', 'bombing', 'arrested')
# ('dozen', 'hackers', 'announced', 'news', 'bombing', 'arrested')
# ('bombing', 'kings', 'cross', 'arrested')
# ('dozen', 'terrorists', 'arrested', 'kings', 'cross', 'exploding', 'terrorist', 'bomb')
# ('dozen', 'hawkers', 'announced', 'fake', 'bombing', 'kings', 'cross', 'arrested')
# ('dozen', 'hawkers', 'announcing', 'non', 'existent', 'new', 'kings', 'cross', 'arrested')
# ('dozen', 'hackers', 'announced', 'news', 'bombing', 'arrested')
# ('dozen', 'terrorist', 'arrested', 'kings', 'cross', 'planting', 'terrorist', 'bomb')
# ('king', "'s", 'cross', 'dozed', 'hackers', 'announced', 'nonexistent', 'bombing', 'arrested')
# ('dozen', 'hackers', 'announced', 'news', 'bombing', 'arrested')
# ('dozen', 'terrorists', 'arrested', 'kings', 'cross', 'planting', 'terrorism', 'bomb')
# ('king', "'s", 'cross', 'dozed', 'hackers', 'announced', 'nonexistent', 'bombing', 'arrested')
# ('bombing', 'kings', 'cross', 'arrested')
# ('dozen', 'hawkers', 'claims')
# ('dozen', 'hawkers', 'announcing', 'non', 'existent', 'new', 'bomber', 'kings', 'cross', 'arrested')
# ('dozen', 'hawkers', 'arrested', 'kings', 'cross', 'planting', 'terrorism', 'bomb')
# ('dozen', 'hackers', 'announced', 'news', 'bombing', 'arrested')
# ('dozen', 'hawkers', 'making', 'claims')
# ('dozen', 'hawkers', 'claims')
# ('dozen', 'hawkers', 'arrested', 'kings', 'cross', 'planting', 'terrorist', 'bomb')
# ('dozen', 'hawkers', 'claims')
# ('dozen', 'hackers', 'announced', 'news', 'bombing', 'kings', 'cross', 'arrested')
# ('dozen', 'hawkers', 'claims')
# ('dozen', 'hawkers', 'arrested', 'kings', 'cross', 'planting', 'terrorist', 'bomb')
# ('dozen', 'hawkers', 'claims')
# ('dozen', 'hawkers', 'claims')
# ('dozen', 'hawkers', 'announcing', 'news', 'non', 'existent', 'bomber', 'kings', 'cross', 'arrested')
# ('dozen', 'hackers', 'announced', 'news', 'nonexistent', 'bombing', 'kings', 'cross', 'arrested')
# ('dozen', 'hawkers', 'announcing', 'non', 'existent', 'anarchist', 'bombing', 'king', "'s", 'cross', 'arrested')
# ('dozen', 'hawkers', 'claims')
# ('bombing', 'kings', 'cross', 'arrested')
# ('dozen', 'hawkers', 'false', 'claims', 'anarchic', 'bombing', 'arrested')
# ('bombing', 'kings', 'cross', 'arrested')
# ('dozen', 'hawkers', 'announcing', 'news', 'nonexistent', 'anarchist', 'bombing', 'king', "'s", 'cross', 'arrested')
# ('bombing', 'kings', 'cross', 'arrested')
# ('dozen', 'hawkers', 'arrested', 'kings', 'cross', 'planting', 'terrorist', 'bomb')
# ('dozen', 'hawkers', 'arrested', 'king', 'cross', 'planting', 'terrorist', 'bomb')
# ('dozed', 'hackers', 'announced', 'nonexistent', 'bombing', 'kings', 'cross', 'arrested')
# ('dozen', 'hawkers', 'announcing', 'news', 'nonexistent', 'anarchist', 'bombing', 'king', "'s", 'cross', 'arrested')
# ('dozen', 'hawkers', 'announcing', 'nonexistent', 'anarchist', 'bombing', 'king', "'s", 'cross', 'arrested')
# ('bombing', 'kings', 'cross', 'arrested')
# ('dozen', 'hawkers', 'claims', 'non', 'existent', 'anarchic', 'bombing', 'arrested')
# ('dozen', 'hawkers', 'arrested', 'king', 'cross', 'planting', 'terrorist', 'bomb')
# ('dozen', 'hawker', 'announcing', 'non', 'existent', 'anarchist', 'bombing', 'kings', 'cross', 'arrested')
# ('dozen', 'hackers', 'announced', 'news', 'nonexistent', 'bombing', 'king', "'s", 'cross', 'arrested')
# ('dozen', 'hawkers', 'announcing', 'non', 'existent', 'anarchists', 'bombing', 'kings', 'cross', 'arrested')
# ('dozen', 'hawkers', 'announcing', 'news', 'nonexistent', 'anarchist', 'bombing', 'king', "'s", 'cross', 'arrested')
#
# Tree #8
# --------
# ('charge', 'embezzlement', 'court')
# ('charge', 'embezzlement', 'court')
# ('charge', 'embezzlement', 'courts')
# ('charge', 'embezzlement', 'courts')
# ('charge', 'embezzlement', 'artillery')
# ('charge', 'embezzlement', 'artillery')
# ('charge', 'embezzlement', 'artillery')
# ('charge', 'embezzlement', 'courts')
# ('charge', 'embezzlement', 'charge')
# ('charge', 'embezzlement', 'charge')
# ('charge', 'embezzlement', 'failed', 'managers')
# ('charge', 'embezzlement', 'failed', 'mangers')
# ('charge', 'embezzlement', 'artillery', 'cancelled')
# ('charge', 'embezzlement', 'failed', 'mangers')
# ('charge', 'embezzlement')
# ('charge', 'embezzlement')
# ('accusation', 'embezzlement', 'arrest', 'result')
# ('charge', 'embezzlement', 'failed', 'mangers')
# ('accusation', 'embezzlement', 'result')
# ('accusation', 'embezzlement', 'consequence')
# ('charge', 'embezzlement', 'court')
# ('allegation', 'embezzlement', 'consequence')
# ('charge', 'embezzlement', 'canterbury', 'artillery', 'managers')
# ('charge', 'embezzlement', 'artillery', 'canceled')
# ('allegation', 'embezzlement', 'manager', 'coventry')
# ('counts', 'charge', 'embezzlement')
# ('charge', 'embezzlement', 'artillery', 'worry')
# ('charge', 'embezzlement', 'canterbury', 'artillery', 'managers')
# ('charge', 'embezzlement')
# ('charge', 'embezzlement')
# ('allegation', 'embezzlement', 'manager', 'canterbury')
# ('counts', 'charge', 'embezzlement')
# ('charge', 'embezzlement', 'artillery', 'canceled')
# ('charge', 'embezzlement', 'counts')
# ('charge', 'embezzlement', 'counts')
# ('charge', 'embezzlement', 'canterbury', 'artillery', 'came')
# ('charge', 'embezzlement', 'court')
# ('allegation', 'embezzlement', 'manager', 'canterbury')
# ('charge', 'embezzlement', 'canterbury', 'artillery', 'came')
# ('charge', 'embezzlement', 'counts')
# ('charge', 'embezzlement', 'artillery', 'worry')
# ('charge', 'embezzlement', 'court')
# ('charge', 'embezzlement', 'counts')
# ('charge', 'embezzlement', 'counts')
# ('charge', 'embezzlement', 'artillery', 'cancelled')
# ('charge', 'embezzlement', 'artillery', 'worry', 'according', 'manager')
# ('charge', 'embezzlement', 'canterbury', 'artillery', 'jury')
# ('charge', 'embezzlement', 'artillery', 'worry', 'according', 'manager')
# ('allegation', 'embezzlement', 'manger', 'canterbury')
# ('charge', 'embezzlement', 'artillery', 'cancelled')
# ('charge', 'embezzlement', 'canterbury', 'artillery', 'came')
# ('charge', 'embezzlement', 'canterbury', 'artillery', 'enquiry')
# ('charge', 'embezzlement', 'canterbury', 'artillery', 'managers')
# ('charge', 'embezzlement', 'canterbury', 'artillery', 'according', 'investigating', 'manager')
# ('charge', 'embezzlement', 'canterbury', 'artillery', 'found', 'managers', 'enquiry')
# ('charge', 'embezzlement', 'canterbury', 'artillery', 'found', 'managers', 'enquiry')
# ('charge', 'embezzlement', 'canterbury', 'artillery', 'jury')
# ('charge', 'embezzlement', 'canterbury', 'artillery', 'mounts', 'enquiry')
# ('charge', 'embezzlement', 'management', 'canterbury')
# ('charge', 'embezzlement', 'artillery', 'worry', 'according', 'manager')
# ('charge', 'embezzlement', 'canterbury', 'artillery', 'came')
# ('charge', 'embezzlement', 'management', 'canterbury', 'artillery', 'according', 'managers', 'enquiry')
# ('charge', 'embezzlement', 'canterbury', 'artillery', 'manager', "'s", 'enquiry')
# ('charge', 'embezzlement', 'management', 'canterbury')
# ('charge', 'embezzlement', 'canterbury', 'artillery', 'according', 'investigating', 'manager')
# ('charge', 'embezzlement', 'canterbury', 'artillery')
# ('charge', 'embezzlement', 'canterbury', 'artillery', 'according', 'investigating', 'manager')
# ('charge', 'embezzlement', 'canterbury', 'artillery', 'manager', "'s", 'enquiry')
# ('charge', 'embezzlement', 'canterbury', 'artillery', 'according', 'manager', 'undertaking', 'enquiry')
# ('charge', 'embezzlement', 'artillery', 'worry', 'according', 'manager')
# ('charge', 'embezzlement', 'canterbury', 'artillery', 'mounts', 'according', 'inquiry')
# ('charge', 'embezzlement', 'canterbury', 'artillery', 'according', 'managers', 'inquiry')
# ('charge', 'embezzlement', 'management', 'canterbury', 'artillery', 'according', 'manager', "'s", 'inquiry')
#
# Tree #9
# --------
# ('clash', 'street', 'constables', 'arrested')
# ('clash', 'street', 'people', 'morley', 'leeds')
# ('clash', 'street', 'people', 'morley', 'leeds')
# ('clash', 'street', 'people', 'morley', 'leeds')
# ('clash', 'street', 'people', 'morley', 'leeds')
# ('clash', 'street', 'constables', 'arrested')
# ('clash', 'streets', 'morley', 'opposition', 'municipals')
# ('clash', 'street', 'constables', 'arrested')
# ('clash', 'streets', 'morley', 'opposition', 'municipal', 'acts', 'power')
# ('clash', 'street', 'people', 'morley', 'leeds')
# ('multiple', 'powers', 'leeds', 'crashed')
# ('clash', 'streets', 'people', 'municipal', 'power', 'morley', 'leeds')
# ('clash', 'street', 'morley', 'opposition')
# ('clash', 'streets', 'morley', 'opposition', 'municipal', 'power')
# ('clash', 'street', 'constables', 'arrested')
# ('clash', 'streets', 'people', 'municipal', 'power', 'morley', 'leeds')
# ('clash', 'street', 'constables', 'arrested')
# ('clash', 'streets', 'people', 'municipal', 'power', 'morley', 'leeds')
# ('police', 'involved', 'clash')
# ('police', 'involved', 'clash', 'constituency', 'leeds')
# ('clash', 'streets', 'morley', 'municipal', 'power', 'opposition')
# ('clash', 'streets', 'morley', 'municipal', 'power', 'opposition')
# ('clash', 'constituency', 'morley', 'leeds', 'police', 'involved')
# ('multiple', 'powers', 'leeds', 'crashed')
# ('clash', 'parties', 'leeds')
# ('clash', 'partied', 'morley', 'leeds', 'opposition', 'party', 'police', 'involved')
# ('clash', 'parties', 'leeds')
# ('multiple', 'powers', 'leeds', 'crashed')
# ('multiple', 'powers', 'leeds', 'crashed')
# ('clash', 'street', 'municipal', 'partied', 'leeds', 'morley', 'opposition', 'party', 'police', 'involved')
# ('multiple', 'powers', 'leeds', 'clashed')
# ('clash', 'leeds', 'multiple', 'powers')
# ('clash', 'parties', 'leeds')
# ('clash', 'street', 'municipal', 'powers', 'leeds', 'constables', 'injured')
# ('clash', 'parties', 'leeds')
# ('clash', 'street', 'morley', 'opposition')
# ('clash', 'streets', 'people', 'municipal', 'power', 'morley', 'leeds')
# ('clash', 'street', 'municipal', 'partied', 'leeds', 'morley', 'opposition', 'party', 'police', 'involved')
# ('clash', 'street', 'constables', 'arrested')
# ('clash', 'streets', 'morley', 'municipal', 'power', 'opposition')
# ('clash', 'street', 'municipal', 'partied', 'leeds', 'morley', 'opposition', 'party', 'police', 'involved')
# ('clash', 'parties', 'leeds')
# ('clash', 'parties', 'leeds', 'opposition', 'party', 'injuries')
# ('clash', 'street', 'constables', 'arrested')
# ('clash', 'street', 'morley', 'opposition')
# ('clash', 'powers', 'leeds', 'opposition', 'party', 'members', 'injured')
# ('clash', 'street', 'municipal', 'powers', 'leeds', 'constables', 'injured')
# ('clash', 'street', 'morley', 'opposition')
# ('clash', 'streets', 'morley', 'opposition')
# ('clash', 'streets', 'morley', 'opposition')
# ('clash', 'streets', 'morley', 'opposition')
# ('clash', 'street', 'municipal', 'partied', 'leeds', 'morley', 'opposition', 'party', 'police', 'involved')
# ('clash', 'street', 'morley', 'opposition')
# ('clash', 'powers', 'leeds', 'opposition', 'party', 'constables', 'injured')
# ('clash', 'street', 'municipal', 'power', 'opposition', 'morley', 'leeds')
# ('clash', 'street', 'municipal', 'powers', 'leeds', 'party', 'opposition', 'constables', 'injured')
# ('clash', 'street', 'municipal', 'power', 'opposition', 'morley', 'leeds')
# ('clash', 'street', 'constables', 'arrested')
# ('clash', 'street', 'constables', 'arrested')
# ('clash', 'street', 'constables', 'arrested')
# ('clash', 'street', 'municipal', 'power', 'opposition', 'morley', 'leeds')
# ('clash', 'street', 'morley', 'opposition')
# ('clash', 'street', 'constables', 'arrested')
# ('clash', 'streets', 'municipal', 'powers', 'opposition', 'party', 'morley', 'leeds', 'constables', 'injured')
# ('clash', 'street', 'municipal', 'parties', 'morley', 'leeds', 'party', 'opposition', 'constables', 'injured')
# ('clash', 'street', 'morley', 'opposition')
# ('clash', 'street', 'powers', 'leeds', 'opposition', 'party', 'constables', 'injured')
# ('clash', 'street', 'people', 'municipal', 'powers', 'morley', 'leeds', 'constables', 'injured')
# ('clash', 'street', 'municipal', 'powers', 'leeds', 'party', 'opposition', 'constables', 'injured')
# ('clash', 'street', 'powers', 'leeds', 'opposition', 'party', 'constables', 'injured')
# ('clash', 'street', 'municipal', 'parties', 'morley', 'leeds', 'party', 'opposition', 'constables', 'injured')
# ('clash', 'street', 'municipal', 'powers', 'morley', 'leeds', 'party', 'opposition', 'constables', 'injured')
#
# Tree #16
# --------
# ('recalled', 'mayor', 'coventry', 'wife', 'charged')
# ('major', 'wife', 'sent', 'prison')
# ('mayor', 'coventry', 'wife', 'sentenced')
# ('mayor', 'coventry', 'wife', 'council', 'worker', 'sent', 'prison', 'strike', 'related', 'incidents')
# ('mayor', 'coventry', 'wife', 'council', 'member', 'sent', 'prison', 'strike', 'related', 'incidents')
# ('mayor', 'coventry', 'wife', 'council', 'member', 'sent', 'prison', 'strike', 'related', 'incidents')
# ('mayer', 'coventry', 'wife', 'sentenced')
# ('mayor', 'coventry', 'wife', 'council', 'member', 'sent', 'prison', 'strike', 'related', 'incidents')
# ('mayor', 'coventry', 'wife', 'council', 'member', 'sentenced', 'prison', 'strike', 'related', 'offences')
# ('sentences', 'handed', 'mayor', 'cardiff', 'wife', 'political', 'offences')
# ('recalled', 'major', 'wife')
# ('recalled', 'major', 'wife')
# ('recalled', 'major', 'wife')
# ('recalled', 'major', 'wife')
# ('mayor', 'coventry', 'wife', 'council', 'member', 'sentenced', 'prison', 'strike', 'related', 'offences')
# ('mayor', 'coventry', 'wife', 'sentenced')
# ('mayor', 'coventry', 'wife', 'sentenced')
# ('mayor', 'coventry', 'wife', 'council', 'member', 'sentenced', 'prison', 'strike', 'related', 'offences')
# ('recalled', 'mayor', 'coventry', 'wife', 'charged')
# ('recalled', 'mayor', 'coventry', 'wife', 'charged')
# ('recalled', 'major', 'wife')
# ('recalled', 'mayor', 'coventry', 'wife', 'charges')
# ('mayor', 'coventry', 'wife', 'sentenced')
# ('mayor', 'coventry', 'wife', 'sentenced')
# ('recalled', 'mayor', 'coventry', 'wife', 'charged')
# ('mayor', 'coventry', 'wife', 'council', 'member', 'sentenced', 'prison', 'strike', 'related', 'offences')
# ('sentences', 'handed', 'mayor', 'cardiff', 'wife', 'political', 'offences')
# ('major', 'wife', 'sent', 'prison')
# ('recalled', 'mayor', 'coventry', 'wife', 'charged')
# ('mayor', 'coventry', 'wife', 'sentenced')
# ('mayor', 'wife', 'member', 'borough', 'council', 'sentenced', 'prison', 'sure', 'guilty')
# ('sentences', 'handed', 'mayor', 'cardiff', 'wife', 'political', 'offences')
# ('major', 'wife', 'sent', 'prison')
# ('sentences', 'handed', 'members', 'council', 'mayor', 'coventry', 'wife', 'political', 'offences')
# ('recalled', 'major', 'wife')
# ('recalled', 'mayor', 'coventry', 'wife', 'charged')
# ('mayor', 'wife', 'member', 'borough', 'council', 'sentenced', 'prison', 'sure', 'guilty')
# ('recalled', 'major', 'wife')
# ('mayor', 'wife', 'member', 'borough', 'council', 'sentenced', 'prison', 'sure', 'guilty')
# ('mayor', 'wife', 'member', 'borough', 'council', 'sentenced', 'prison', 'known', 'guilty')
# ('recalled', 'mayor', 'coventry', 'wife', 'charged')
# ('mayor', 'wife', 'member', 'borough', 'council', 'sentenced', 'prison', 'known', 'guilty')
# ('major', 'wife', 'sent', 'prison')
# ('major', 'wife', 'sent', 'prison')
# ('recalled', 'major', 'wife')
# ('mayor', 'coventry', 'wife', 'member', 'council', 'sentenced', 'prison', 'political', 'offences')
# ('mayor', 'coventry', 'wife', 'member', 'municipal', 'council', 'sentenced', 'prison', 'political', 'offences')
# ('mayor', 'coventry', 'wife', 'sentenced')
# ('mayor', 'coventry', 'wife', 'member', 'municipal', 'council', 'sentenced', 'prison', 'political', 'offences')
# ('mayor', 'wife', 'sent', 'prison')
# ('mayor', 'wife', 'sent', 'prison')
# ('recalled', 'mayor', 'coventry', 'wife', 'member', 'municipal', 'council', 'sentenced', 'prison', 'political', 'offences')
# ('mayor', 'wife', 'sent', 'prison')
# ('mayor', 'coventry', 'wife', 'sentenced')
# ('recalled', 'mayor', 'coventry', 'wife', 'close', 'friend', 'arrested', 'offences')
# ('recalled', 'mayor', 'coventry', 'wife', 'member', 'municipal', 'council', 'sentenced', 'prison', 'strike', 'related', 'offences')
# ('mayor', 'wife', 'member', 'borough', 'council', 'sentenced', 'prison', 'know', 'guilty')
# ('mayor', 'coventry', 'wife', 'council', 'member', 'sentenced', 'prison', 'strike', 'related', 'offences')
# ('mayor', 'wife', 'member', 'borough', 'council', 'sentenced', 'prison', 'known', 'guilty', 'alleged', 'offence')
# ('recalled', 'mayor', 'coventry', 'wife', 'charged', 'offences')
# ('recalled', 'mayor', 'coventry', 'wife', 'charged', 'offences')
# ('mayor', 'wife', 'member', 'borough', 'council', 'sentenced', 'prison', 'strike', 'related', 'offences')
# ('recalled', 'mayor', 'coventry', 'wife', 'council', 'sent', 'prison')
# ('mayor', 'wife', 'member', 'borough', 'councillor', 'sentenced', 'prison', 'strike', 'related', 'offences')
# ('recalled', 'mayor', 'coventry', 'wife', 'close', 'friend', 'arrested', 'strike', 'related', 'offences')
# ('mayor', 'coventry', 'wife', 'member', 'council', 'sentenced', 'prison', 'strike', 'related', 'offences')
# ('recalled', 'mayor', 'coventry', 'wife', 'member', 'municipal', 'council', 'sentenced', 'prison', 'strike', 'related', 'offences')
# ('recalled', 'mayor', 'coventry', 'wife', 'sentenced', 'prison', 'strike', 'offences')
# ('recalled', 'mayor', 'coventry', 'wife', 'council', 'sent', 'prison', 'strike', 'related', 'activities')
# ('recalled', 'mayor', 'coventry', 'wife', 'member', 'municipal', 'council', 'sentenced', 'prison', 'strike', 'related', 'offences')
# ('mayor', 'coventry', 'wife', 'sentenced', 'municipal', 'council', 'strike', 'related', 'offences')
# ('recalled', 'mayor', 'coventry', 'wife', 'member', 'council', 'sentenced', 'prison', 'strike', 'related', 'activities')
# ('recalled', 'mayor', 'coventry', 'wife', 'member', 'municipal', 'council', 'sentenced', 'prison', 'strike', 'related', 'offences')
#
# Tree #20
# --------
# ('ouch', 'cried', 'oyster', 'eater', '100', 'dime', 'dime', 'store', '30')
# ('ouch', 'cried', 'running', 'oyster', 'paid')
# ('ouch', 'cried', 'easter', 'pear')
# ('ouch', 'cried', 'oyster', 'eater', '100', 'dime', 'dime', 'store', '30')
# ('ouch', 'cried', 'running', 'oyster', 'table', 'paid')
# ('ouch', 'cried', 'running', 'oyster', 'table', 'paid')
# ('ouch', 'cried', 'easter', 'pear')
# ('ouch', 'cried', 'oyster', 'eater', 'sold', 'table', '100', 'dollars', 'bought', '50', 'cents', 'dime', 'store')
# ('ouch', 'cried', 'oyster', 'eater', 'sold', 'pearl', '100', 'dollars', 'table', 'bought', '50', 'cents', 'dime', 'store')
# ('ouch', 'cried', 'oyster', 'eater', '100', 'dime', 'dime', 'store', '30')
# ('ouch', 'cried', 'running', 'oyster', 'table', 'paid')
# ('ouch', 'cried', 'oyster', 'eater', 'man', 'bought', '100', '30', 'dime', 'store')
# ('ouch', 'cried', 'running', 'oyster', 'table', 'paid')
# ('ouch', 'cried', 'oyster', 'eater', 'man', 'bought', '100', '30', 'dime', 'store')
# ('pearl', 'cunning', 'oyster', 'catcher', 'ouch', 'sold', '100', 'sold', '300')
# ('ouch', 'cried', 'oyster', 'eater', 'sold', 'pearl', 'person', 'table', '100', 'dollars', 'bought', '50', 'cents', 'dime', 'store')
# ('ouch', 'cried', 'easter', 'pear')
# ('spent', '100', 'dollars', 'pearl', 'oyster', 'costing', '30', 'cents')
# ('spent', '100', 'dollars', 'pearl', 'oyster', 'costing', '30', 'cents')
# ('pearl', 'cunning', 'oyster', 'catcher', 'ouch', 'sold', '100', 'sold', '300')
# ('pearl', 'cunning', 'oyster', 'catcher', 'cried', 'ouch', 'sold', '100', 'sold', '300')
# ('spent', '100', 'pounds', 'pearl', 'come', 'oyster', 'costing', '30', 'cents')
# ('ouch', 'cried', 'cunning', 'oyster', 'eater', 'table', 'bought', '100', 'paid')
# ('ouch', 'cried', 'oyster', 'eater', 'pearl', 'sold', 'table', '100', 'dollars', 'bought', '50', 'cents', 'dime', 'store')
# ('ouch', 'cried', 'oyster', 'eater', 'man', 'bough', '100', '30', 'dime', 'store')
# ('spent', '100', 'pounds', 'pearl', 'came', 'oyster', 'costing', '30', 'cents')
# ('ouch', 'cried', 'oyster', 'eater', 'pearl', 'sold', 'table', '100', 'dollars', 'bought', '50', 'cents', 'dime', 'store')
# ('ouch', 'cried', 'cunning', 'easter', 'pearl')
# ('ouch', 'cried', 'oyster', 'eater', 'pearl', 'sold', 'table', '100', 'dollars', 'bought', '30', 'cents', 'dime', 'store')
# ('ouch', 'cunning', 'oyster', 'eater', 'pearl', 'table', 'bought', '100', 'pounds', 'table', 'bought', 'thirty', 'pence')
# ('pearl', 'cunning', 'oyster', 'eater', 'cried', 'ouch', 'sold', '100', 'sold', '300')
# ('ouch', 'cried', 'oyster', 'eater', 'man', 'bought', '100', '30', 'dime', 'store')
# ('ouch', 'oyster', 'finding', 'pearl', 'table', 'bought', '£', '100')
# ('ouch', 'oyster', 'eater', 'pearl', 'th', 'table', 'bought', '£', '100')
# ('ouch', 'cried', 'oyster', 'eater', 'pearl', 'table', 'bought', '100', 'dollars', 'bought', '30', 'cents', 'dime', 'store')
# ('ouch', 'cried', 'cunning', 'oyster', 'eater', 'table', 'bought', '100', 'bought', '30', 'dime', 'store')
# ('ouch', 'cried', 'cunning', 'oyster', 'eater', 'pearl', 'table', 'bought', '100', 'dollars', 'bought', '30', 'cents', 'dime', 'store')
# ('ouch', 'cunning', 'oyster', 'eater', 'pearl', 'table', 'bought', '100', 'pounds', 'person', 'bought', 'market', '30', 'pence')
# ('ouch', 'cunning', 'oyster', 'eater', 'pearl', 'table', 'bought', '100', 'pounds', 'pearl', 'cost', '30', 'pence', 'dime', 'store')
# ('ouch', 'cried', 'cunning', 'oyster', 'eater', 'person', 'table', 'bought', '100', 'bought', '30', 'dime', 'store')
# ('ouch', 'cried', 'cunning', 'easter', 'pearl')
# ('ouch', 'cried', 'cunning', 'easter', 'pearl')
# ('ouch', 'cried', 'cunning', 'oyster', 'eater', '.a', 'pearl', 'table', 'bought', '100', 'paid')
# ('ouch', 'cried', 'cunning', 'oyster', 'eater', 'pearl', 'table', 'bought', '£', '100', 'bought', '30', 'pence', 'dime', 'store')
# ('ouch', 'oyster', 'eater', 'pearl', 'table', 'bought', '£', '100')
# ('ouch', 'cried', 'cunning', 'oyster', 'eater', 'pearl', 'table', 'bought', '£', '100', 'cost', '30', 'cents', 'dime', 'store')
# ('ouch', 'cried', 'cunning', 'oyster', 'eater', 'pearl', 'sold', '100', 'sold', '300')
# ('ouch', 'cried', 'cunning', 'easter', 'pearl')
# ('ouch', 'cried', 'cunning', 'oyster', 'eater', 'pearl')
# ('ouch', 'oyster', 'eater', 'pearl', 'table', 'bought', '£', '100')
# ('ouch', 'cried', 'cunning', 'oyster', 'eater', 'pearl', 'sold', '100', 'sold', '300')
# ('ouch', 'oyster', 'eater', 'pearl', 'table', 'bought', '£', '100')
# ('ouch', 'cried', 'cunning', 'oyster', 'eater', 'pearl', 'person', 'table', 'bought', 'fir', '£', '100', 'bought', '30', 'dime', 'store')
# ('ouch', 'cried', 'cunning', 'oyster', 'eater', 'pearl', 'table', 'bought', '100', 'pounds', 'pearl', 'cost', '30', 'pence', 'dime', 'store')
# ('ouch', 'cried', 'cunning', 'oyster', 'eater', 'pearl', 'sold', '100', 'sold', '300')
# ('ouch', 'cried', 'cunning', 'oyster', 'eater', 'pearl', 'bought', '100', 'sold', '300')
# ('ouch"!cried', 'cunning', 'oyster', 'eater', 'pearl', 'bought', '100', 'sold', '300')
# ('ouch', 'yelled', 'oyster', 'eater', 'peal', 'table', 'bought', '£', '100')
# ('ouch', 'yelled', 'oyster', 'eater', 'peal', 'diner', 'table', 'bought', '£', '100')
# ('ouch', 'cried', 'cunning', 'oyster', 'eater', 'pearl')
# ('ouch', 'cried', 'cunning', 'oyster', 'eater', 'pearl', 'table', 'bought', '£', '100', 'cost', '30', 'pence', 'dime', 'store')
# ('ouch', 'yelled', 'oyster', 'eater', 'peal', 'diner', 'table', 'bought', '£', '100')
# ('ouch', 'cried', 'cunning', 'oyster', 'eater', 'pearl', 'table', 'bought', '100', 'pounds', 'pearl', 'cost', '30', 'pence', 'dime', 'store')
# ('ouch', 'yelled', 'oyster', 'eater', 'pearl', 'table', 'bough', '100', 'pounds')
# ('ouch"!cried', 'cunning', 'oyster', 'eater', 'pearl', 'table', 'bought', '100', 'cost', '30', 'dime', 'store')
# ('ouch', 'cried', 'cunning', 'oyster', 'eater', 'pearl')
# ('ouch', 'cried', 'cunning', 'oyster', 'eater', 'pearl', 'table', 'bought', '100', 'pounds', 'pearl', 'cost', '30', 'pence', 'dime', 'store')
# ('ouch', 'cried', 'cunning', 'oyster', 'eater', 'pearl', 'table', 'bought', '100', 'pounds', 'cost', '30', 'pence', 'dime', 'store')
# ('ouch', 'cried', 'cunning', 'oyster', 'eater', 'pearl', 'person', 'table', 'bought', '£', '100', '30', 'pence', 'dime', 'store')
# ('ouch', 'yelled', 'oyster', 'eater', 'pearl', 'table', 'bought', '100', 'pounds', 'similar', 'cost', '30', 'pence', 'dime', 'store')
# ('ouch', 'cried', 'cunning', 'oyster', 'eater', 'pearl', 'table', 'bought', '£', '100', 'cost', '30', 'pence', 'dime', 'store')
# ('ouch', 'cried', 'cunning', 'oyster', 'eater', 'pearl', 'table', 'bought', '100', 'pounds', 'cost', '30', 'pence', 'dime', 'store')
#
# Tree #22
# --------
# ('true', 'children', 'left')
# ('finding', 'daughter', 'hanged', 'davis', 'halifax', 'killed', '11', 'daughters', 'left')
# ('finding', 'daughter', 'hanged', 'davis', 'halifax', 'killed', '11', 'daughters', 'left')
# ('finding', 'daughter', 'austere', 'cleaned', 'house')
# ('finding', 'daughter', 'austere', 'cleaned', 'house')
# ('finding', 'daughter', 'austere', 'cleaned', 'house')
# ('finding', 'daughter', '19', 'killed', '11', 'children', 'left')
# ('finding', 'daughter', 'hanged', 'davis', 'halifax', 'killed', '11', 'children', 'left')
# ('finding', 'daughter', 'austere', 'cleaned', 'house')
# ('finding', 'daughter', 'inefficient', 'watchmaker', 'davis', 'killed')
# ('finding', 'daughter', 'hanged', 'davis', 'halifax', 'killed', '11', 'children', 'left')
# ('finding', 'daughter', 'hanged', 'davis', 'halifax', 'killed', '11', 'children', 'left')
# ('finding', 'daughter', 'aged', '19', 'killed', '11', 'children', 'left')
# ('finding', 'daughter', 'inefficient', 'watchmaker', 'davis', 'killed')
# ('finding', 'daughter', '19', 'killed', '11', 'children', 'left')
# ('watching', 'daughter', '19', 'austere', 'true', '11', 'children')
# ('finding', 'daughter', '19', 'killed', '11', 'children', 'left')
# ('finding', 'daughter', 'inefficient', 'watchmaker', 'davis', 'killed')
# ('finding', 'daughter', 'austere', 'cleaned', 'house')
# ('finding', 'daughter', 'hanged', 'davies', 'halifax', 'killed', '11', 'children', 'left')
# ('finding', 'daughter', 'austere', 'cleared')
# ('finding', 'daughter', '19', 'killed', '11', 'children', 'left')
# ('finding', 'daughter', '19', 'killed', '11', 'children', 'left')
# ('finding', 'daughter', 'inefficient', 'watchmaker', 'davies', 'killed')
# ('true', 'children', 'left')
# ('watching', 'daughter', '19', 'bennett', 'austere', 'true', '11', 'children')
# ('chris', 'killed', 'daughter', '19', 'finding', 'insufficient', '11', 'children', 'left')
# ('chris', 'killed', 'daughter', '19', 'finding', 'insufficient', 'children', 'left')
# ('finding', 'daughter', 'austere', 'cleared')
# ('finding', 'daughter', 'hanged', 'davies', 'halifax', 'killed', '11', 'children', 'left')
# ('chris', 'killed', 'daughter', '19', 'finding', 'insufficient', 'children', 'left')
# ('finding', 'daughter', '19', 'killed', '11', 'children', 'left')
# ('true', 'children', 'left')
# ('chris', 'killed', 'daughter', '19', 'finding', 'insufficient', '11', 'children', 'left')
# ('finding', 'daughter', 'hanged', 'davies', 'halifax', 'killed', '11', 'children', 'left')
# ('true', 'children', 'left')
# ('watching', 'daughter', '19', 'clock', 'maker', 'austere', 'true', '11', 'children')
# ('finding', 'daughter', 'hanged', 'davies', 'halifax', 'killed', '11', 'children', 'left')
# ('finding', 'daughter', '19', 'insufficiently', 'austere', 'set', 'clearing')
# ('finding', 'daughter', 'insufficient', 'watchmaker', 'davies', 'killed')
# ('watching', 'daughter', '19', 'clockmaker', 'austere', 'true', '11', 'children')
# ('finding', 'daughter', '19', 'insufficient', 'watchmaker', 'davies', 'killed')
# ('finding', '19', 'year', 'old', 'daughter', 'insufficient', 'watchmaker', 'davis', 'warrington', 'killed')
# ('watching', 'daughter', '19', 'clockmaker', 'austere', 'true', '11', 'children')
# ('true', 'children', 'left')
# ('true', 'children', 'left')
# ('finding', 'daughter', '19', 'insufficient', 'watchmaker', 'davis', 'warrington', 'killed')
# ('watching', 'daughter', '19', 'clockmaker', 'austere', 'true', '11', 'children')
# ('finding', 'daughter', '19', 'insufficiently', 'austere', 'watchmaker', 'davis', 'warrington', 'killed')
# ('watching', 'daughter', '19', 'clockmaker', 'austere', 'true', '11', 'children')
# ('finding', 'daughter', '19', 'insufficient', 'chris', 'killed', 'true', '11', 'children', 'left')
# ('finding', 'daughter', '19', 'insufficient', 'chris', 'killed', 'true', '11', 'children', 'left')
# ('finding', 'daughter', '19', 'insufficiently', 'austere', 'killed', '11', 'children', 'left')
# ('true', 'children', 'left')
# ('true', 'children', 'left')
# ('true', 'children', 'left')
# ('finding', 'daughter', '19', 'insufficiently', 'austere', 'davis', 'typesetter', 'set', 'cleaning')
# ('finding', 'daughter', '19', 'insufficient', 'davies', 'watchmaker', 'killer', 'true', 'children', 'left')
# ('finding', 'daughter', '19', 'insufficiently', 'austere', 'davies', 'killed', '11', 'children', 'left')
# ('watching', 'daughter', '19', 'watchmaker', 'austere', 'true', '11', 'children')
# ('finding', 'daughter', '19', 'insufficient', 'davies', 'watchmaker', 'halifax', 'killed', 'true', 'children', 'left')
# ('finding', 'daughter', '19', 'insufficiently', 'austere', 'watchmaker', 'davis', 'halifax', 'killed')
# ('finding', 'daughter', '19', 'insufficiently', 'austere', 'davies', 'watchmaker', 'halifax', 'killed', 'true', 'children', 'left')
# ('finding', 'daughter', '19', 'insufficiently', 'austere', 'davies', 'killed', '11', 'children', 'left')
# ('watching', 'daughter', '19', 'insufficiently', 'austere', 'watchmaker', 'killed', 'true', '11', 'children', 'left')
# ('true', 'children', 'left')
# ('watching', 'daughter', '19', 'insufficiently', 'austere', 'watchmaker', 'killed', 'true', '11', 'children', 'left')
# ('finding', 'daughter', '19', 'insufficiently', 'austere', 'davies', 'watchmaker', 'killed', 'true', 'children', 'left')
# ('finding', 'daughter', 'hanged', 'davies', 'halifax', 'killed', '11', 'children', 'left')
# ('finding', 'daughter', '19', 'insufficient', 'davis', 'watchmaker', 'halifax', 'killed', 'true', '11', 'children', 'left')
# ('finding', 'daughter', '19', 'insufficient', 'davies', 'watchmaker', 'halifax', 'killed', 'true', '11', 'children', 'left')
# ('finding', 'daughter', '19', 'insufficiently', 'austere', 'davies', 'watchmaker', 'halifax', 'killed', 'true', 'children', 'left')
#
# Tree #26
# --------
# ('nancy', 'pregnant', 'professor', 'tell', 'wife', 'despite', 'telling', 'nancy')
# ('nancy', 'affair', 'college', 'tutor', 'fell', 'pregnant', 'told', 'wife', 'left')
# ('nancy', 'pregnant', 'professor', 'tell', 'wife', 'despite', 'telling', 'nancy')
# ('nancy', 'pregnant', 'professor', 'tell', 'wife', 'despite', 'promising', 'nancy')
# ('nancy', 'told', 'professor', "'s", 'wife', 'affair', 'hoe', 'pregnant')
# ('nancy', 'pregnant', 'professors', 'child', 'affair', 'tell', 'wife', 'despite', 'telling', 'nancy')
# ('nancy', 'affair', 'professor', 'told', 'wife', 'leave')
# ('nancy', 'told', 'professor', "'s", 'wife', 'affair', 'hoe', 'pregnant')
# ('nancy', 'affair', 'married', 'college', 'professor', 'pregnant', 'leave', 'wife')
# ('nancy', 'affair', 'married', 'college', 'professor', 'pregnant', 'leave', 'wife')
# ('nancy', 'told', 'professor', "'s", 'wife', 'affair', 'pregnant')
# ('nancy', 'affair', 'college', 'professor', 'threatened', 'tell', 'wife', 'wife', 'left')
# ('nancy', 'told', 'professors', 'wife', 'affair', 'pregnant')
# ('nancy', 'affair', 'professor', 'told', 'wife', 'leave')
# ('nancy', 'told', 'professor', "'s", 'wife', 'affair', 'pregnant')
# ('nancy', 'affair', 'college', 'tutor', 'fell', 'pregnant', 'told', 'wife', 'left')
# ('nancy', 'affair', 'college', 'professor', 'threatened', 'tell', 'wife', 'wife', 'left')
# ('nancy', 'affair', 'professor', 'told', 'wife', 'leave')
# ('nancy', 'affair', 'college', 'professor', 'fell', 'pregnant', 'told', 'wife', 'left')
# ('nancy', 'told', 'professor', "'s", 'wife', 'affair', 'pregnant')
# ('nancy', 'affair', 'college', 'professor', 'fell', 'pregnant', 'told', 'leave', 'wife', 'speak', 'wife', 'left')
# ('nancy', 'affair', 'college', 'professor', 'threatened', 'tell', 'wife', 'nancy', 'fell', 'pregnant', 'left', 'nancy', 'told', 'wife', 'wife', 'left')
# ('nancy', 'pregnant', 'professors', 'child', 'affair', 'tell', 'wife', 'despite', 'telling', 'nancy')
# ('nancy', 'told', 'professors', 'wife', 'affair', 'pregnant')
# ('nancy', 'pregnant', 'professors', 'child', 'affair', 'tell', 'wife', 'despite', 'telling', 'nancy')
# ('nancy', 'affair', 'professor', 'told', 'wife', 'leave')
# ('nancy', 'affair', 'married', 'college', 'professor', 'pregnant', 'professor', 'leave', 'wife')
# ('nancy', 'affair', 'college', 'professor', 'tell', 'wife', 'nancy', 'fell', 'pregnant', 'refused', 'nancy', 'told', 'wife', 'wife', 'left')
# ('nancy', 'affair', 'married', 'college', 'professor', 'pregnant', 'professor', 'leave', 'wife')
# ('nancy', 'affair', 'college', 'professor', 'tell', 'wife', 'nancy', 'fell', 'pregnant', 'refused', 'nancy', 'told', 'wife', 'wife', 'left')
# ('nancy', 'pregnant', 'professor', "'s", 'child', 'affair', 'tell', 'wife', 'despite', 'telling', 'nancy')
# ('nancy', 'affair', 'married', 'college', 'professor', 'pregnant', 'professor', 'leave', 'wife')
# ('nancy', 'affair', 'college', 'professor', 'tell', 'wife', 'nancy', 'pregnant', 'refused', 'nancy', 'angry', 'told', 'professor', "'s", 'wife', 'wife', 'left')
# ('nancy', 'affair', 'married', 'college', 'professor', 'pregnant', 'professor', 'leave', 'wife')
# ('nancy', 'affair', 'college', 'professor', 'fell', 'pregnant', 'told', 'leave', 'wife', 'speak', 'told', 'wife', 'left')
# ('nancy', 'affair', 'married', 'college', 'professor', 'told', 'tell', 'wife', 'nancy', 'told', 'pregnant', 'refused', 'nancy', 'angry', 'told', 'wife', 'angry', 'left')
# ('nancy', 'affair', 'college', 'professor', 'fell', 'pregnant', 'professor', 'told', 'nancy', 'leave', 'wife', 'speak', 'told', 'wife', 'left')
# ('nancy', 'affair', 'professor', 'nancy', 'pregnant', 'child', 'tell', 'wife', 'nancy', 'told', 'wife')
# ('nancy', 'affair', 'professor', 'told', 'wife', 'leave')
# ('nancy', 'affair', 'professor', 'nancy', 'pregnant', 'child', 'leave', 'wife', 'nancy', 'told', 'wife')
# ('nancy', 'affair', 'professor', 'nancy', 'pregnant', 'professor', 'professor', 'tell', 'wife', '.nancy', 'professor', 'nancy', 'told', 'professors', 'wife')
# ('nancy', 'affair', 'professor', 'pregnant', 'child', 'leave', 'wife', 'nancy', 'told', 'wife')
# ('nancy', 'affair', 'professor', 'pregnant', 'told', 'wife', 'leave')
# ('nancy', 'affair', 'college', 'professor', 'fell', 'pregnant', 'professor', 'told', 'nancy', 'leave', 'wife', 'speak', 'told', 'wife', 'left')
# ('nancy', 'affair', 'college', 'lecturer', 'carrying', 'child', 'threatened', 'tell', 'wife', "n't", 'tell', 'nancy')
# ('nancy', 'affair', 'married', 'college', 'professor', 'pregnant', 'professor', 'leave', 'wife')
# ('nancy', 'affair', 'college', 'lecturer', 'carrying', 'child', 'threatened', 'tell', 'wife', "n't", "n't")
# ('nancy', 'affair', 'married', 'college', 'professor', 'told', 'tell', 'wife', 'told', 'pregnant', 'refused', 'nancy', 'angry', 'told', 'professor', "'s", 'wife', 'angry', 'left')
# ('nancy', 'affair', 'college', 'professor', 'nancy', 'pregnant', 'professors', 'child', 'professor', 'leave', 'wife', 'telling', 'professor', 'nancy', 'professor', 'nancy', 'told', 'professors', 'wife', 'professors', 'wife', 'left', 'professor')
# ('nancy', 'affair', 'college', 'professor', 'fell', 'pregnant', 'baby', 'speak', 'told', 'wife', 'left', 'professor', 'promised', 'leave', 'wife', 'nancy')
# ('nancy', 'affair', 'college', 'professor', 'fell', 'pregnant', 'baby', 'told', 'speak', 'told', 'wife', 'left', 'professor', 'promised', 'leave', 'wife', 'nancy')
# ('nancy', 'affair', 'college', 'lecturer', 'carrying', 'child', 'threatened', 'tell', 'wife', "n't")
# ('nancy', 'affair', 'married', 'college', 'professor', 'bangor', 'nancy', 'pregnant', 'professor', 'leave', 'wife')
# ('nancy', 'affair', 'married', 'college', 'professor', 'nancy', 'recently', 'pregnant', 'professors', 'child', 'professor', 'promised', 'nancy', 'leave', 'wife')
# ('nancy', 'affair', 'college', 'lecturer', 'carrying', 'child', 'threatened', 'tell', 'wife', 'leave', "n't")
# ('nancy', 'affair', 'college', 'teacher', 'pregnant', 'child', 'threatened', 'tell', 'wife', 'leave', "n't")
# ('nancy', 'affair', 'college', 'professor', 'pregnant', 'told', 'wife', 'leave', 'happened')
# ('nancy', 'affair', 'college', 'teacher', 'recently', 'pregnant', 'child', 'threatened', 'tell', 'wife', 'leave')
# ('nancy', 'affair', 'college', 'professor', 'nancy', 'recently', 'pregnant', 'professor', "'s", 'child', 'professor', 'promised', 'leave', 'wife', 'nancy', 'told', 'refused', 'speak', 'nancy', 'told', 'professor', "'s", 'wife', 'professor', "'s", 'wife', 'let')
# ('nancy', 'affair', 'married', 'college', 'professor', 'professor', 'told', 'tell', 'wife', 'told', 'pregnant', 'refused', 'nancy', 'told', 'professor', "'s", 'wife', 'affair', 'professor', "'s", 'wife', 'angry', 'left')
# ('nancy', 'affair', 'college', 'professor', 'pregnant', 'tod', 'wife', 'leave', 'happened')
# ('nancy', 'affair', 'college', 'professor', 'recently', 'pregnant', 'child', 'professor', 'leave', 'wife', 'ignoring', 'nancy', "'s", 'recently', 'nancy', 'told', 'professor', "'s", 'wife', 'left', 'professor')
# ('nancy', 'affair', 'college', 'professor', 'pregnant', 'tod', 'leave', 'wife', 'told', 'wife', 'left')
# ('nancy', 'affair', 'college', 'professor', 'nancy', 'recently', 'pregnant', 'professor', "'s", 'child', 'professor', 'promised', 'nancy', 'leave', 'wife', 'nancy', 'told', 'pregnant', 'professor', 'refused', 'nancy', 'told', 'professor', "'s", 'wife', 'affair', 'professor', "'s", 'wife', 'upset', 'left', 'professor')
# ('nancy', 'affair', 'married', 'college', 'professor', 'nancy', 'recently', 'pregnant', 'professor', "'s", 'child', 'professor', 'promised', 'nancy', 'leave', 'wife')
# ('nancy', 'affair', 'professor', 'pregnant', 'child', 'leave', 'wife', 'nancy', 'told', 'wife')
# ('nancy', 'affair', 'married', 'college', 'professor', 'nancy', 'recently', 'pregnant', 'professor', "'s", 'child', 'professor', 'leave', 'wife', 'nancy', 'told', 'refused', 'nancy', 'told', 'professors', 'wife', 'professor', "'s", 'wife', 'let')
# ('nancy', 'affair', 'married', 'college', 'professor', 'recently', 'pregnant', 'told', 'leave', 'wife', "n't", 'nancy', 'told', 'wife', 'left')
# ('nancy', 'affair', 'married', 'college', 'professor', 'professor', 'told', 'leave', 'wife', 'told', 'pregnant', 'refused', 'nancy', 'told', 'wife', 'affair', 'professor', "'s", 'wife', 'angry', 'left', 'professor')
# ('nancy', 'affair', 'college', 'professor', 'recently', 'pregnant', 'child', 'professor', 'promised', 'leave', 'wife', 'ignoring', 'nancy', "'s", 'lately', 'nancy', 'told', 'wife', 'affair', 'wife', 'left', 'professor')
# ('nancy', 'affair', 'college', 'professor', 'recently', 'pregnant', 'child', 'professor', 'told', 'leave', 'wife', 'recently', 'ignoring', 'nancy', 'instead', 'nancy', 'told', 'wife', 'affair', 'professor', "'s", 'wife', 'left')
# ('nancy', 'affair', 'college', 'professor', 'nancy', 'recently', 'pregnant', 'professors', 'child', 'professor', 'told', 'nancy', 'leave', 'wife', 'nancy', 'told', 'baby', 'professor', 'refuses', 'nancy', 'told', 'professors', 'wife', 'affair', 'professors', 'wife', 'left')
# ('nancy', 'affair', 'married', 'college', 'professor', 'nancy', 'recently', 'pregnant', 'professor', "'s", 'child', 'professor', 'promised', 'nancy', 'leave', 'wife', 'nancy', 'told', 'pregnant', 'professor', 'refused', 'nancy', 'told', 'professor', "'s", 'wife', 'affair', 'professor', "'s", 'wife', 'upset', 'left', 'professor')
#
# Tree #27
# --------
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broken', 'rushed', 'theatre', 'missed', 'lecture')
# ('sophie', 'clock', 'alarm', 'broke', 'meaning', 'sh', 'missed', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'woke', 'late', 'lecture', 'dressed', 'missed', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'woke', 'missed', 'lecture', 'dressed', 'missed', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'woke', 'missed', 'important', 'lecture', 'dressed', 'missed', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'woke', 'missed', 'important', 'lecture', 'dressed', 'missed', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'woke', 'missed', 'important', 'lecture', 'dressed', 'missed', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'woke', 'realise', 'missed', 'important', 'lecture', 'dressed', 'quickly', 'missed', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broke', 'realised', 'late')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broke', 'realised', 'late')
# ('day', 'sophie', "'s", 'alarm', 'clock', 'broken', 'rushed', 'theatre', '-one')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'released', 'late', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'released', 'later', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broke', 'woke', 'realized', 'late')
# ('sophie', "'s", 'alarm', 'clock', 'broke', 'morning', 'realising', 'late', 'bus', 'school')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broke', 'released', 'later', 'morning', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broke', 'overslept', 'woke', 'realised', 'late')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broke', 'overslept', 'woke', 'realised', 'late')
# ('day', 'sophie', "'s", 'alarm', 'clock', 'broken', 'rushed', 'theater')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broke', 'overslept', 'woke', 'realised', 'late')
# ('sophie', 'clock', 'alarm', 'broke', 'meaning', 'sh', 'missed', 'lecture')
# ('sophie', 'clock', 'alarm', 'broke', 'meaning', 'sh', 'missed', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broke', 'overslept', 'woke', 'realised', 'late')
# ('morning', 'sophie', "'s", 'alarm', 'realised', 'missed', 'important', 'lecture', 'dressed', 'quickly', 'realised', 'missed', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broke', 'overslept', 'woke', 'realised', 'late')
# ('day', 'sophie', "'s", 'alarm', 'clock', 'broken', 'rushed', 'theater')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broken', 'rushed', 'theatre', 'missed', 'lecture')
# ('sophie', "'s", 'clock', 'alarm', 'broke', 'meaning', 'missed', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broke', 'released', 'late', 'morning', 'lecture')
# ('day', 'sophie', "'s", 'alarm', 'clock', 'broken', 'rushed', 'theatre', 'missed', 'lecture')
# ('day', 'sophie', "'s", 'alarm', 'clock', 'broken', 'rushed', 'theatre', 'missed', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broke', 'released', 'late', 'important', 'lecture')
# ('sophie', "'s", 'alarm', 'clock', 'broke', 'morning', 'realising', 'late', 'bus', 'school')
# ('day', 'sophie', "'s", 'alarm', 'clock', 'broken', 'rushed', 'theatre', 'missed', 'lecture')
# ('sophie', "'s", 'alarm', 'clock', 'broke', 'morning', 'realising', 'late', 'bus', 'school')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broke', 'woke', 'find', 'late', 'important', 'lecture', 'realised', 'late', 'rushed', 'lecture', 'theatre', 'arrived', 'missed', 'important', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broke', 'realised', 'late', 'important', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broke', 'woke', 'find', 'late', 'important', 'lecture', 'realised', 'late', 'rushed', 'lecture', 'theatre', 'arrived', 'missed', 'important', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broke', 'woke', 'found', 'late', 'important', 'lecture', 'realised', 'late', 'rushed', 'lecture', 'hall', 'found', 'missed', 'important', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broke', 'realised', 'late', 'important', 'lecture')
# ('day', 'sophie', 'alarm', 'clock', 'broke', 'overslept', 'dressed', 'quickly', 'ran', 'theatre', 'missed', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broke', 'slept', 'realised', 'late', 'important', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broken', 'rushed', 'theatre', 'missed', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broke', 'woke', 'realised', 'late', 'important', 'lecture', 'rushed', 'lecture', 'theatre', 'found', 'missed', 'important', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broke', 'realising', 'late', 'bus', 'school')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broke', 'realising', 'late', 'bus', 'school')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broke', 'realising', 'late', 'bus', 'school')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broke', 'slept', 'realised', 'late', 'important', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broken', 'rushed', 'theatre', 'missed', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'realised', 'late', 'important', 'lecture', 'dressed', 'quickly', 'realised', 'missed', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broke', 'overslept', 'woke', 'realised', 'late')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broke', 'realising', 'late', 'bus', 'school')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broken', 'rushed', 'theater', 'missed', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broke', 'overslept', 'dressed', 'quickly', 'possible', 'ran', 'lecture', 'theatre', 'time', 'lecture', 'missed', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broken', 'rushed', 'theatre', 'missed', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'realised', 'late', 'important', 'lecture', 'dressed', 'quickly', 'realised', 'missed', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broke', 'rushed', 'theatre', 'missed', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broke', 'overslept', 'dressed', 'quickly', 'possible', 'ran', 'lecture', 'theatre', 'time', 'lecture', 'missed', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broke', 'realising', 'late', 'bus', 'school')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broke', 'late', 'lecture', 'rushed', 'theatre', 'missed', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broke', 'woke', 'realised', 'late', 'important', 'lecture', 'lecture', 'theatre', 'missed', 'important', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broke', 'woke', 'realised', 'late', 'important', 'lecture', 'rushed', 'lecture', 'theatre', 'missed', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broke', 'late', 'lecture', 'ran', 'theatre', 'missed', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broke', 'overslept', 'realised', 'late', 'lecture', 'theater', 'realised')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'overslept', 'woke', 'realized', 'late', 'important', 'lecture', 'dressed', 'quickly', 'possible', 'ran', 'lecture', 'hall', 'missed', 'lecture')
# ('morning', 'sophie', "'s", 'alarm', 'clock', 'broke', 'overslept', 'awoke', 'realised', 'late', 'important', 'lecture', 'dressed', 'quickly', 'ran', 'lecture', 'theatre', 'lecture', 'theatre', 'sophie', 'missed', 'lecture')
# ...
# ('heat', 'colorado', 'causes', 'forest', 'forest', 'causes', 'global', 'warming', 'global', 'warming', 'causes', 'death')
# ('weather', 'colorado', 'warm', 'dry', 'leads', 'soil', 'hearing', 'leads', 'forest', 'fires')
# ('weather', 'colorado', 'hot', 'dry')
# ('heat', 'colorado', 'causes', 'forest', 'forest', 'causes', 'global', 'warming', 'warming', 'earth')
# ('weather', 'colorado', 'hot', 'dry')
# ('weather', 'colorado', 'hot', 'dry')
# ('weather', 'hot', 'cool', 'colorado', 'lead', 'greenhouse', 'effect')
# ('heat', 'colorado', 'summer', 'leads', 'forest', 'causes', 'carbon', 'monoxide', 'released', 'cause', 'global', 'warming', 'warming', 'earth')
# ('weather', 'colorado', 'warm', 'dry', 'leads', 'soil', 'heating', 'leads', 'forest', 'fires')
# ('weather', 'hot', 'cool', 'colorado', 'lead', 'greenhouse', 'effect')
# ('weather', 'colorado', 'hot', 'dry', 'summer', 'drys', 'plants')
# ('weather', 'colorado', 'hot', 'summer', 'resulting', 'forest', 'fires', 'releases', 'carbon', 'monoxide', 'leads', 'global', 'warming', 'warming', 'earth')
# ('hot', 'dry', 'weather', 'colorado', 'causes', 'plants', 'smoke', 'turn', 'contributes', 'global', 'warming')
# ('weather', 'colorado', 'hot', 'dry', 'leads', 'global', 'warming')
# ('hot', 'dry', 'weather', 'colorado', 'causes', 'plants', 'burn', 'produces', 'smoke', 'turn', 'contributes', 'global', 'warming')
# ('weather', 'colorado', 'hot', 'summer', 'resulting', 'forest', 'fire', 'releases', 'carbon', 'monoxide', 'leads', 'global', 'warming', 'earth', "'s", 'warming')
# ('weather', 'colorado', 'hot', 'dry', 'leads', 'global', 'warming')
# ('weather', 'colorado', 'hot', 'dry', 'summer', 'leads', 'global', 'warming')
# ('weather', 'colorado', 'hot', 'summer', 'resulting', 'forest', 'fires', 'release', 'carbon', 'monoxide', 'leads', 'global', 'warming', 'earths', 'warming')
# ('weather', 'colorado', 'hot', 'dry', 'summer', 'dries', 'plants')
# ('weather', 'colorado', 'hot', 'dry', 'summer', 'causes', 'plants', 'soil', 'dry', 'catch', 'fire', 'burn', 'producing', 'smoke', 'contributes', 'global', 'warming')
# ('weather', 'colorado', 'hot', 'dry', 'summer', 'dries', 'plants')
# ('weather', 'colorado', 'hot', 'dry', 'summer', 'dries', 'plants')
# ('weather', 'colorado', 'hot', 'dry', 'summer', 'leads', 'global', 'warming')
# ('weather', 'summer', 'colorado', 'hot', 'dry', 'leads', 'forest', 'fires', 'fires', 'draw', 'moisture', 'soil', 'releasing', 'carbon', 'monoxide', 'leads', 'global', 'warming', 'earths', 'warming')
# ('weather', 'colorado', 'hot', 'dry', 'summer', 'dried', 'vegetation', 'forest', 'fires')
# ('weather', 'colorado', 'hot', 'dry', 'summer', 'dries', 'plants')
# ('weather', 'colorado', 'hot', 'dry', 'summer', 'dries', 'plants')
# ('weather', 'colorado', 'hot', 'dry', 'summer', 'dries', 'moisture', 'soil', 'leading', 'forest', 'fires', 'fires', 'release', 'smoke', 'air', 'containing', 'carbon', 'monoxide', 'contributes', 'global', 'warming', 'earths', 'temperature')
# ('weather', 'colorado', 'hot', 'dry', 'summer', 'causes', 'plants', 'soil', 'dry', 'dry', 'vegetation', 'catches', 'fire', 'burning', 'produces', 'smoke', 'adds', 'carbon', 'dioxide', 'atmosphere', 'contributes', 'global', 'warming')
# ('weather', 'hot', 'dry', 'colorado', '.this', 'lead', 'green', 'house', 'effect')
# ('weather', 'colorado', 'warm', 'dry', 'leads', 'soil', 'heating', 'leads', 'forest', 'fires')
# ('weather', 'colorado', 'warm', 'dry', 'leads', 'soil', 'heating', 'catching', 'fire', 'causes', 'forest', 'fires')
# ('weather', 'hot', 'dry', 'colorado', 'dries', 'plants', 'easily', 'catch', 'fire', 'fire', 'releases', 'smoke', 'carbon', 'monoxide', 'leads', 'green', 'house', 'effect')
# ('weather', 'colorado', 'hot', 'dry', 'summer', 'dries', 'vegetation', 'causing', 'forest', 'fires', 'lots', 'forest', 'fires', 'cause', 'high', 'levels', 'carbon', 'monoxide', 'contributing', 'climate', 'change')
# ('weather', 'colorado', 'warm', 'dry', 'leads', 'soil', 'heating', 'catching', 'fire', 'causes', 'forest', 'fires')
# ('weather', 'colorado', 'hot', 'dry', 'summer', 'dries', 'vegetation', 'causing', 'forest', 'fires', 'lots', 'forest', 'fires', 'cause', 'high', 'levels', 'carbon', 'monoxide', 'contributing', 'climate', 'change', 'increasing', 'temperatures')
# ('weather', 'colorado', 'hot', 'dry', 'summer', 'dries', 'plants')
# ('weather', 'colorado', 'hot', 'dry', 'summer', 'leads', 'global', 'warming')
# ('weather', 'colorado', 'warm', 'dry', 'leads', 'soil', 'heating', 'catching', 'fire', 'causes', 'forest', 'fires')
# ('weather', 'colorado', 'hot', 'dry', 'summer', 'removes', 'moisture', 'soil', 'dries', 'plants', 'grow', 'dry', 'vegetation', 'catches', 'fire', 'easily', 'leading', 'frequent', 'forest', 'fires', 'fires', 'release', 'smoke', 'containing', 'carbon', 'monoxide', 'atmosphere', 'smoke', 'contributes', 'global', 'warming', 'increasing', 'temperature')
# ('weather', 'colorado', 'hot', 'dry', 'summer', 'drys', 'plants', 'grow', 'dry', 'vegetation', 'catches', 'fire', 'easily', 'forest', 'fires', 'creating', 'lots', 'carbon', 'monoxide', 'creates', 'global', 'warming', 'temperatures', 'higher')
# ('weather', 'colorado', 'hot', 'dry', 'summer', 'removes', 'moisture', 'soil', 'causing', 'plants', 'dry', 'causes', 'vegetation', 'grows', 'easily', 'catch', 'fire', 'fire', 'releases', 'smoke', 'containing', 'carbon', 'monoxide', 'atmosphere', 'contributing', 'global', 'warming', 'increases', 'temperature')
# ('weather', 'colorado', 'hot', 'dry', 'summer', 'removes', 'moisture', 'soil', 'dries', 'plants', 'grow', 'dry', 'vegetation', 'catches', 'fire', 'easily', 'leading', 'frequent', 'forest', 'fires', 'fires', 'release', 'smoke', 'containing', 'carbon', 'monoxide', 'atmosphere', 'smoke', 'contributes', 'global', 'warming', 'increasing', 'temperatures')
# ('weather', 'colorado', 'hot', 'dry', 'summer', 'dries', 'plants')
# ('weather', 'colorado', 'hot', 'dry', 'leads', 'soil', 'dirt', 'drying', 'destroying', 'vegetation', 'dry', 'soil', 'catches', 'fire', 'easily', 'produces', 'forest', 'fires', 'fires', 'produce', 'smoke', 'release', 'carbon', 'monoxide', 'air', 'gas', 'increases', 'global', 'warming', 'consequently', 'heat', 'rises')
# ('weather', 'hot', 'dry', 'colorado', 'dries', 'plants', 'easily', 'catch', 'fire', 'fire', 'release', 'smoke', 'carbon', 'monoxide', 'leads', 'green', 'house', 'effect')
# ('weather', 'colorado', 'hot', 'dry', 'summer', 'dries', 'plants')
# ('weather', 'colorado', 'hot', 'dry', 'summer', 'moisture', 'soil', 'dries', 'plants')
# ('weather', 'colorado', 'hot', 'dry', 'summer', 'removes', 'moisture', 'soil', 'dries', 'plants', 'grow', 'dry', 'vegetation', 'catches', 'fire', 'easily', 'leading', 'frequent', 'forest', 'fires', 'fires', 'release', 'smoke', 'containing', 'carbon', 'monoxide', 'atmosphere', 'smoke', 'contributes', 'global', 'warming', 'increasing', 'temperatures')
#
# Tree #56
# --------
# ('talking', 'laughing', 'cheerfully', 'mrs')
# ('middle', 'joyous', 'occasion', 'woman', 'lurched', 'table', 'bullet', 'head', 'sir', 'removed')
# ('middle', 'joyous', 'occasion', 'woman', 'lurched', 'table', 'bullet', 'head', 'sir', 'removed')
# ('talking', 'laughing', 'mrs', 'bullet', 'ear', 'killed')
# ('laughing', 'joking', 'mrs', 'weaver', 'fell', 'bullet', 'head', 'mr', 'weaver', 'pulled', 'knife', 'head')
# ('laughing', 'joking', 'mrs', 'weaver', 'fell', 'bullet', 'head', 'mr', 'weaver', 'pulled', 'knife', 'head')
# ('middle', 'joyous', 'occasion', 'woman', 'lurched', 'table', 'bullet', 'head', 'sir', 'removed')
# ('laughing', 'mrs', 'weaver', 'shrieked', 'fell', 'table')
# ('middle', 'joyous', 'occasion', 'woman', 'lurched', 'table', 'bullet', 'head', 'sir', 'removed')
# ('whilst', 'laughing', 'cheerfully', 'mrs', 'weaver', 'streaked', 'table', 'bullet', 'head', 'husband', 'pulled', 'knife')
# ('whilst', 'laughing', 'cheerfully', 'mrs', 'weaver', 'streaked', 'table', 'bullet', 'head', 'husband', 'pulled', 'knife')
# ('talking', 'laughing', 'cheerfully', 'mrs')
# ('whilst', 'talking', 'laughing', 'mrs', 'bullet', 'ear', 'killed', 'mrs', 'hunt', 'pulled', 'bloodied', 'knife', 'chest')
# ('whilst', 'talking', 'laughing', 'mrs', 'bullet', 'ear', 'killed', 'mrs', 'hunt', 'pulled', 'bloodied', 'knife', 'chest')
# ('talking', 'laughing', 'cheerfully', 'mrs', 'weaver', 'fell', 'shriek', 'bullet', 'wound', 'head')
# ('laughing', 'mrs', 'weaver', 'shrieked', 'fell', 'table')
# ('whilst', 'laughing', 'joking', 'mrs', 'weaver', 'fell', 'bullet', 'head', 'mr.', 'weaver', 'pulled', 'knife', 'head')
# ('whilst', 'talking', 'laughing', 'mrs', 'bullet', 'ear', 'killed', 'mrs', 'hunt', 'pulled', 'bloodied', 'knife', 'chest')
# ('whilst', 'laughing', 'joking', 'mrs', 'weaver', 'fell', 'bullet', 'head', 'mr', 'weaver', 'pulled', 'knife', 'head')
# ('whilst', 'talking', 'laughing', 'mrs', 'bullet', 'ear', 'time', 'reached', 'dead', 'mrs', 'hunt', 'pulled', 'bloodied', 'knife', 'chest')
# ('whilst', 'laughing', 'cheerfully', 'mrs', 'weaver', 'streaked', 'table', 'bullet', 'head', 'husband', 'pulled', 'knife')
# ('laughing', 'cheerfully', 'mrs', 'weaver', 'streaked', 'fell', 'table', 'bullet', 'head', 'husband', 'pulled', 'knife')
# ('middle', 'joyous', 'occasion', 'woman', 'lurched', 'table', 'bullet', 'head', 'sir', 'removed')
# ('whilst', 'talking', 'laughing', 'mrs', 'bullet', 'ear', 'time', 'reached', 'dead', 'mr', 'hunt', 'pulled', 'bloodied', 'knife', 'chest')
# ('middle', 'joyous', 'occasion', 'woman', 'lurched', 'table', 'bullet', 'head', 'sir', 'removed')
# ('whilst', 'talking', 'laughing', 'mrs', 'suddenly', 'fell', 'forward', 'bullet', 'ear', 'time', 'reached', 'dead', 'mr', 'frost', 'pulled', 'bloodied', 'knife', 'chest')
# ('whilst', 'laughing', 'joking', 'mrs', 'weaver', 'fell', 'bullet', 'head', 'mr', 'weaver', 'pulled', 'knife', 'head')
# ('laughing', 'cheerfully', 'mrs', 'weaver', 'streaked', 'fell', 'table', 'bullet', 'head', 'sir', 'john', 'pulled', 'knife')
# ('talking', 'laughing', 'mrs', 'weaver', 'shrieked', 'fell', 'table')
# ('middle', 'joyful', 'occasion', 'woman', 'lurched', 'table', 'bullet', 'head', 'sir', 'removed', 'removed', 'bloodstained', 'knife', 'heart')
# ('talking', 'laughing', 'cheerfully', 'mrs', 'weaver', 'shriek', 'fell', 'bullet', 'wound', 'head')
# ('whilst', 'laughing', 'joking', 'mrs', 'weaver', 'fell', 'bullet', 'head', 'mr', 'pulled', 'knife', 'head')
# ('whilst', 'laughing', 'joking', 'mrs', 'weaver', 'fell', 'dead', 'bullet', 'head', 'sir', 'john', 'pulled', 'bloody', 'knife', 'head')
# ('middle', 'joyful', 'occasion', 'woman', 'lurched', 'table', 'bullet', 'head', 'sir', 'removed', 'bloodstained', 'knife', 'heart')
# ('whilst', 'talking', 'laughing', 'cheerfully', 'mrs', 'weaver', 'suddenly', 'shrieked', 'fell', 'forwards', 'bullet', 'ear', 'reached', 'dead', 'mr', 'frost', 'pulled', 'blood', 'stained', 'knife', 'chest')
# ('talking', 'laughing', 'mrs', 'weaver', 'shrieked', 'fell', 'table')
# ('whilst', 'laughing', 'joking', 'mrs', 'weaver', 'fell', 'dead', 'bullet', 'head', 'sir', 'jon', 'pulled', 'blood', 'soaked', 'knife', 'head')
# ('talking', 'laughing', 'mrs', 'weaver', 'shrieked', 'fell', 'table')
# ('walking', 'laughing', 'mrs', 'weaver', 'suddenly', 'fell', 'forward', 'bullet', 'holes')
# ('talking', 'laughing', 'cheerfully', 'mrs', 'wilson', 'suddenly', 'lurched', 'table', 'bullet', 'head', 'sir', 'john', 'removed', 'blood', 'stained', 'knife', 'heart')
# ('walking', 'laughing', 'mrs', 'weaver', 'suddenly', 'fell', 'forward', 'bullet', 'holes', 'heart')
# ('talking', 'laughing', 'cheerfully', 'mrs', 'weaver', 'shriek', 'feel', 'bullet', 'wound', 'head')
# ('talking', 'laughing', 'cheerfully', 'mrs', 'weaver', 'shriek', 'suddenly', 'fell', 'forward', 'bullet', 'wound', 'head')
# ('talking', 'cheerfully', 'mrs', 'weaver', 'shrieked', 'fell', 'table', 'bullet', 'head', 'sir', 'john', 'reached', 'pulled', 'knife')
# ('laughing', 'talking', 'mrs', 'weaver', 'shrieked', 'fell', 'table')
# ('walking', 'laughing', 'mrs', 'weaver', 'suddenly', 'fell', 'forward', 'bullet', 'holes', 'heart')
# ('talking', 'cheerfully', 'mrs', 'weaver', 'shrieked', 'fell', 'table', 'bullet', 'head', 'sir', 'john', 'reached', 'pulled', 'knife', 'heart')
# ('talking', 'laughing', 'mrs', 'weaver', 'suddenly', 'fell', 'forward', 'bullet', 'holes', 'heart')
# ('laughing', 'joking', 'mrs', 'weaver', 'suddenly', 'fell', 'forward', 'bullet', 'holes', 'heart')
# ('laughing', 'joking', 'mrs', 'weaver', 'suddenly', 'fell', 'forward', 'bullet', 'holes', 'heart')
# ('laughing', 'joking', 'mrs', 'weaver', 'suddenly', 'fell', 'forward', 'bullet', 'shots', 'heart')
# ('talking', 'laughing', 'cheerfully', 'mrs', 'weaver', 'shriek', 'suddenly', 'fell', 'forward', 'bullet', 'wound', 'head')
# ('laughing', 'talking', 'mrs', 'weaver', 'fell', 'forward', 'suddenly', 'bullets', 'heart', 'stood', 'sir', 'john', 'plucked', 'knife', 'head')
# ('talking', 'laughing', 'mrs', 'weaver', 'shrieked', 'fell', 'table')
# ('laughing', 'talking', 'cheerfully', 'mrs', 'weaver', 'suddenly', 'shriek', 'fell', 'forward', 'table', 'bullet', 'wound', 'head')
# ('laughing', 'talking', 'cheerfully', 'mrs', 'weaver', 'suddenly', 'shriek', 'fell', 'forwards', 'table', 'bullet', 'wound', 'head', 'dead', 'sir', 'john', 'approached', 'plucked', 'blood', 'stained', 'knife', 'heart')
# ('whilst', 'talking', 'laughing', 'cheerfully', 'mrs', 'weaver', 'suddenly', 'shriek', 'fell', 'forwards', 'bullet', 'hear', 'reached', 'found', 'dead', 'mr', 'frost', 'pulled', 'blood', 'stained', 'knife', 'chest')
# ('talking', 'laughing', 'miss', 'weaver', 'suddenly', 'shrieked', 'fell', 'forward', 'table', 'bullet', 'wound', 'head', 'reached', 'dead', 'sir', 'john', 'pulled', 'knife', 'heart')
# ('talking', 'cheerfully', 'mrs', 'weaver', 'shriek', 'fell', 'table', 'bullet', 'head', 'sir', 'john', 'reached', 'pulled', 'pulled', 'bloody', 'knife', 'heart')
# ('whilst', 'laughing', 'joking', 'mrs', 'weaver', 'suddenly', 'fell', 'desk', 'bullet', 'head', 'sir', 'john', 'pulled', 'blood', 'soaked', 'knife', 'heart')
# ('whilst', 'talking', 'cheerfully', 'mrs', 'weaver', 'shriek', 'fell', 'table', 'bullet', 'wound', 'head', 'sir', 'john', 'bloody', 'knife', 'heart')
# ('wile', 'talking', 'laughing', 'miss', 'weaver', 'suddenly', 'shrieked', 'fell', 'forward', 'table', 'bullet', 'wound', 'head', 'reached', 'dead', 'sir', 'john', 'pulled', 'knife', 'heart')
# ('talking', 'laughing', 'miss', 'weaver', 'suddenly', 'shrieked', 'fell', 'forward', 'table', 'bullet', 'wound', 'head', 'reached', 'dead', 'sir', 'john', 'pulled', 'blood', 'stained', 'knife', 'heart')
# ('talking', 'laughing', 'cheerfully', 'mrs', 'weaver', 'let', 'loud', 'shriek', 'fell', 'forward', 'bullet', 'head', 'stood', 'sir', 'john', 'plucked', 'knife', 'heart')
# ('talking', 'laughing', 'cheerfully', 'mrs', 'weaver', 'suddenly', 'terrific', 'shriek', 'fell', 'forward', 'bullet', 'head', 'reached', 'found', 'dead', 'sir', 'john', 'pulled', 'blood', 'stained', 'knife', 'heart')
# ('whilst', 'talking', 'cheerfully', 'mrs', 'weaver', 'terrific', 'shriek', 'fell', 'table', 'bullet', 'wound', 'head', 'reached', 'sir', 'john', 'instantly', 'pulled', 'blood', 'stained', 'knife', 'heart')
# ('talking', 'laughing', 'cheerfully', 'miss', 'weaver', 'suddenly', 'terrific', 'shriek', 'fell', 'forward', 'table', 'bullet', 'wound', 'head', 'reached', 'found', 'dead', 'sir', 'john', 'plucked', 'blood', 'stained', 'knife', 'heart')
# ('laughing', 'joking', 'cheerfully', 'mrs', 'weaver', 'suddenly', 'fell', 'forward', 'desk', 'bullet', 'head', 'reached', 'sir', 'john', 'pulled', 'blood', 'soaked', 'knife', 'heart')
# ('talking', 'laughing', 'cheerfully', 'mrs', 'weaver', 'let', 'loud', 'shriek', 'fell', 'forward', 'bullet', 'head', 'stood', 'sir', 'john', 'plucked', 'knife', 'heart')
# ('talking', 'laughing', 'cheerfully', 'miss', 'weaver', 'suddenly', 'lurched', 'table', 'bullet', 'wound', 'head', 'sir', 'john', 'removed', 'blood', 'stained', 'knife', 'heart')
# ('talking', 'laughing', 'cheerfully', 'miss', 'weaver', 'suddenly', 'terrific', 'shriek', 'fell', 'forward', 'table', 'bullet', 'wound', 'head', 'reached', 'found', 'dead', 'sir', 'john', 'plucked', 'blood', 'stained', 'knife', 'heart')
