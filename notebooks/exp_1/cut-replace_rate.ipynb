# %% [markdown]
# # Cut-replace rate: how much is a sentence cut vs. replaced

# %% [markdown]
# ## 1 Setup

# %% [markdown]
# Flags

# %%
SAVE_FIGURES = False

# %% [markdown]
# Setup the database

# %%
import os, sys
sys.path.insert(1, os.path.abspath('../..'))
import analysis
analysis.setup('spreadr_exp_1')
# Out:
# <module 'gists.models' from '/home/sl/Code/Research/interpretation-experiment/analysis/notebooks/exp_1/spreadr/gists/models.py'>

# %% [markdown]
# Imports for the analysis

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
import numpy as np
from pandas import DataFrame
from scipy.stats import linregress
import seaborn as sb

from gists.models import Sentence, Tree

from analysis.utils import grouper, memoized, mpl_palette

# %% [markdown]
# ## 2 Cut-replace rate per tree

# %% [markdown]
# First build our data

# %%
trees = Tree.objects.experiment.all()
data = []
order = []
for tree in trees:
    root = tree.root
    order.append({'tree id': tree.id,
                  'root_content_words_count': len(root.content_words)})
    for sentence in tree.sentences.kept.all():
        data.append({'tree id': tree.id,
                     'sentence id': sentence.id,
                     'length': len(sentence.content_words),
                     'length / len(root)': len(sentence.content_words) / len(root.content_words),
                     'diff from root': root.uc_distance(sentence)
                    })
data = DataFrame(data)
root_order = DataFrame(order).sort_values(['root_content_words_count', 'tree id'])

# %% [markdown]
# For each tree, plot the length of a sentence (number of content words relative to number content words of its tree root, so immune so minor changes) as a function of the difference from its tree root (difference taken as distance between bags of content words, so unordered).
#
# On each plot there are 3 interesting spots:
# * a sentence in the upper-left is very close to the root, both in length and content;
# * a sentence in the upper-right is very different to the root, but about the same length; so it's different from its root, because many words are replaced;
# * a sentence in the lower-right is very different to the root, and a lot shorter too; so it's different mainly because it's been croppped a lot.
#
# So, the steeper the slope (downwards), the more a tree has its sentences cut, i.e. words removed. The flatter the slope, the more it has its sentences transformed, i.e. words replaced.
#
# Plots are **ordered by number of content words in the root of the tree**, which correlates a lot to the slope.

# %%
g = sb.lmplot(data=data,
              y='length / len(root)', x='diff from root',
              col='tree id', col_wrap=7, size=1.5,
              col_order=root_order['tree id'])
g.set(xlim=(-0.1, 1.1), ylim=(-0.1, 1.5))
if SAVE_FIGURES:
    g.savefig('/home/sl/Downloads/gistr/cut-replace_rate.png', dpi=300)

# %% [markdown]
# Most trees seem to give flat or negative slope (i.e. the shorter the sentence, the more different it is from its root).
#
# Except #13.

# %% [markdown]
# ## 3 Cut-replace rate ~ number of initial content words, which seem closely related

# %% [markdown]
# First build our data

# %%
slope_content = []
for tree in Tree.objects.experiment.all():
    tree_data = data[data['tree id'] == tree.id]
    slope, intercept, r_value, p_value, std_err = linregress(tree_data['diff from root'],
                                                             tree_data['length / len(root)'])
    slope_content.append({'tree id': tree.id,
                          'root content words count': len(tree.root.content_words),
                          'slope': slope})
slope_content = DataFrame(slope_content)

# %% [markdown]
# In the graph, we'll exclude trees with 15 or more initial content words:

# %%
threshold = 15
too_much_content = sorted([t.id for t in Tree.objects.experiment.all()
                           if len(t.root.content_words) >= threshold])
print('Trees with {} or more initial content words: {}'.format(threshold, too_much_content))
# Out:
# Trees with 15 or more initial content words: [37, 39, 42, 44, 46, 47, 48, 49, 51, 52]

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
axes[0].scatter(slope_content['root content words count'],
                slope_content['slope'])
axes[0].set_title('With long content sentences')
axes[0].set_xlabel('root content words count')
axes[0].set_ylabel('slope')
sb.regplot(ax=axes[1], data=slope_content[~slope_content['tree id'].isin(too_much_content)],
           x='root content words count', y='slope',
           x_jitter=.2, robust=True)
axes[1].set_title('Without long content sentences')
if SAVE_FIGURES:
    fig.savefig('/home/sl/Downloads/gistr/scatter_cut-replace_content.png', dpi=300)

# %% [markdown]
# In the graph above, a more negative 'slope' value means more shortening and less replacement (and vice-versa).
#
# Remarks:
# * With all the trees (left graph), it looks like $y = \frac{1-x}{x}$, or linear with segments.
# * If we take out long content trees (right graph, so it's the left graph truncated at $x < 15$) it's pretty linear: more content words means linearly more cutting and less replacement when you transform. Less content words means you do more replacing. It makes sense: if a sentence is very long, you're likely to remember the beginning, or the end, and forget the rest. If a sentence is very short, you're likely to remember the gist and replace its words.

# %% [markdown]
# The outlier in the bottom left of the left graph (bottom middle in the right graph) is tree #25, which has a very catchy first part ("It's not just for work, it's not just for play"):

# %%
slope_content[slope_content['slope'] <= -1.18]
# Out:
# Empty DataFrame
# Columns: [root content words count, slope, tree id]
# Index: []

# %% [markdown]
# The outlier in the top left of the right graph is tree #13, which is in fact *augmented* by subjects ("Dinosaurs and humans walked the earth at the same time"):

# %%
slope_content[slope_content['slope'] >= .2]
# Out:
#     root content words count     slope  tree id
# 12                         5  0.283855       13

# %% [markdown]
# ## 4 A few more details

# %% [markdown]
# Here are the root sentences for all trees, for a detailed look:

# %%
for tree in Tree.objects.experiment.all():
    print('Tree #{}'.format(tree.id))
    print('--------')
    print(tree.root.text)
    print()
# Out:
# Tree #1
# --------
# The young boy was suddenly hit by the little girl
#
# Tree #2
# --------
# Don't forget to leave the door open when you leave the office
#
# Tree #3
# --------
# Don't forget to leave the door open when you leave the office so that the cleaning person can come in
#
# Tree #4
# --------
# Don't forget to leave the door open when you leave the office so that the people robbing us don't break the windows
#
# Tree #5
# --------
# By the way, I can't come and fetch you, but it's only a dozen kilometers, you can hitch-hike down to the village
#
# Tree #6
# --------
# Can you pay the rent a little earlier this month?
#
# Tree #7
# --------
# They want to keep it all for themselves, and I don't blame them, but it ends up being a rich ghetto
#
# Tree #8
# --------
# This crisis did not develop overnight and it will not be solved overnight
#
# Tree #9
# --------
# Immediately after I become president I will confront this economic challenge head-on by taking all necessary steps
#
# Tree #10
# --------
# We can't point the finger at any political party, responsibility is shared
#
# Tree #11
# --------
# There is no hope for peace, it is a lost cause
#
# Tree #12
# --------
# While our brothers and sisters are being killed, Mubarak and his cronies sit by and do nothing
#
# Tree #13
# --------
# Dinosaurs and humans walked the earth at the same time
#
# Tree #14
# --------
# I'm going to the republican convention not to attack the democratic candidate but to explain to the American people why I support John McCain
#
# Tree #15
# --------
# The lack of transparency in negotiations of an agreement that will affect the fundamental rights of citizens of the world is fundamentally undemocratic
#
# Tree #16
# --------
# Let me show you that I'm innocent and that I didn't do anything wrong, a crime has not been proven here
#
# Tree #17
# --------
# If this proposed regulation had been in place it would have undermined our ability to protect the bald eagle, the grizzly bear and the gray whale
#
# Tree #18
# --------
# I am currently pregnant, and I fear for the safety of my second child once born
#
# Tree #20
# --------
# If builders built houses the way programmers built programs, the first woodpecker to come along would destroy civilization
#
# Tree #22
# --------
# Never doubt that a small group of thoughtful committed citizens can change the world, it is the only thing that ever has
#
# Tree #23
# --------
# All difficult things have their origin in that which is easy, and great things in that which is small
#
# Tree #25
# --------
# It's not just for work, it's not just for play, we think it's the one phone you can use for your entire life
#
# Tree #26
# --------
# The biggest challenge of the 21st century is the irony of technologies of abundance in the hands of those thinking in terms of scarcity
#
# Tree #27
# --------
# This is an outstanding performance by a female actor in a leading role
#
# Tree #28
# --------
# It is clear that the financial system, although improved from where it was in September, is still fragile
#
# Tree #29
# --------
# My Government's overriding priority is to ensure the stability of the British economy
#
# Tree #30
# --------
# This is socialism for the rich. It's bailing out the financiers, the banks, the Wall Streeters.
#
# Tree #31
# --------
# If there is a major attack on this country it will bear the fingerprints of al-qaeda
#
# Tree #32
# --------
# Will you investigate the gravest crimes of the Bush administration, including torture and warrantless wiretapping?
#
# Tree #33
# --------
# We also know that military force will sometimes be necessary
#
# Tree #34
# --------
# This is the most serious financial situation we have known in generations
#
# Tree #36
# --------
# If you ask me I'd slap those tough kids down before they start any trouble, it saves a lot of time and money
#
# Tree #37
# --------
# This kid's been kicked around all his life, born in a slum, mother dead since he was nine, lived for a year and a half in an orphanage when his father was serving a jail term for forgery, he's a wild angry kid, that's all he's ever been
#
# Tree #38
# --------
# Listen I've lived among them all my life, you can't believe a word they say, you know that, they're born liars
#
# Tree #39
# --------
# It is obvious to me that the boy's entire story was flimsy: he claimed he was at the movies during the time of the killing and yet one hour later he couldn't remember the names of the films he saw or who played in them
#
# Tree #40
# --------
# This boy, let's say he's the product of a broken home and a filthy neighbourhood, we can't help that, we get to decide whether he's innocent or guilty
#
# Tree #41
# --------
# It's no secret, children from slum backgrounds are potential menaces to society
#
# Tree #42
# --------
# He was a very old man in a torn jacket, he walked very slowly, he was dragging his left leg and trying to hide it, because he was ashamed, sad that nobody knows him. So he wouldn't really lie, but make himself believe some facts to make himself important.
#
# Tree #43
# --------
# How will the cultural and religious aspects of so many migrants impact E.U. society?
#
# Tree #44
# --------
# They are illegal immigrants until they prove they are escaping a war, or they are persecuted by their government or with the complicity of it. The reality is that only a tiny part of them are refugees, most of them are economic immigrants trying to enter in Italy illegally.
#
# Tree #45
# --------
# One who travels across half the world and is willing to settle in one special place of his or her desire without being invited or granted the right beforehand, cannot be called a real refugee
#
# Tree #54
# --------
# She rested her fork on the edge of her plate and he noticed for the first time that she was wearing no wedding ring. He immediately changed the subject.

# %% [markdown]
# Tree #13, which looks like an outlier in the cut-replace per tree graphs, has:

# %%
print("{} non-spam sentences".format(Tree.objects.get(id=13).sentences.kept.count()))
# Out:
# 40 non-spam sentences

# %% [markdown]
# And here are their content words:

# %%
[s.content_words for s in Tree.objects.get(id=13).sentences.kept.all()]
# Out:
# [('dinosaurs', 'humans', 'walked', 'earth', 'exact', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'earth', 'exact', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'world', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'earth', 'time'),
#  ('dinosauras', 'humans', 'walked', 'earth', 'time'),
#  ('dinosors', 'humans', 'walked', 'earth', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'earth', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'earth', 'exact', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'world', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'world', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'earth', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'earth', 'exact', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'earth', 'exact', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'earth', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'earth', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'earth', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'earth', 'exact', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'earth', 'exact', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'earth', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'earth', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'earth', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'earth', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'earth', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'earth', 'exact', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'earth', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'earth', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'earth', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'earth', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'earth', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'earth', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'earth', 'exact', 'time'),
#  ('dinosaurs', 'human', 'walked', 'earth', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'earth', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'earth', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'earth', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'earth', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'earth', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'earth', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'earth', 'time'),
#  ('dinosaurs', 'humans', 'walked', 'earth', 'time')]

# %% [markdown]
# The same for tree #25:

# %%
[s.content_words for s in Tree.objects.get(id=25).sentences.kept.all()]
# Out:
# [('work', 'play'),
#  ('work', 'play'),
#  ('work', 'play'),
#  ('ust', 'work', 'play', 'think', 'phone', 'life'),
#  ('ust', 'work', 'play', 'think', 'phone', 'life'),
#  ('work', 'play'),
#  ('work', 'play'),
#  ('ust', 'work', 'play', 'think', 'phone', 'life'),
#  ('work', 'play'),
#  ('work', 'play'),
#  ('work', 'play', 'think', 'phone', 'life'),
#  ('work', 'play'),
#  ('work', 'play'),
#  ('work', 'play'),
#  ('work', 'play'),
#  ('work', 'play'),
#  ('work', 'play'),
#  ('work', 'play'),
#  ('work', 'play'),
#  ('work', 'play'),
#  ('work', 'play'),
#  ('work', 'play'),
#  ('work', 'play'),
#  ('work', 'play'),
#  ('work', 'play', 'think', 'phone', 'life'),
#  ('work', 'play'),
#  ('work', 'play', 'think'),
#  ('work', 'play', 'think'),
#  ('work', 'play'),
#  ('work', 'play'),
#  ('work', 'play'),
#  ('work', 'play'),
#  ('work', 'play', 'think', 'phone', 'life'),
#  ('work', 'play', 'think', 'phone'),
#  ('work', 'play', 'think', 'phone', 'use', 'entire', 'life'),
#  ('work', 'play', 'thinks', 'phone', 'user', 'entire', 'life'),
#  ('work', 'play', 'think', 'phone', 'user', 'entire', 'life'),
#  ('work', 'play'),
#  ('work', 'play', 'think', 'phone', 'user', 'entire', 'life'),
#  ('work', 'play', 'think', 'phone', 'life'),
#  ('work', 'play'),
#  ('work', 'play', 'think', 'phone', 'use', 'entire', 'life'),
#  ('work', 'play'),
#  ('work', 'play', 'think', 'phone', 'user', 'entire', 'life'),
#  ('work', 'play', 'think', 'phone', 'use', 'rest', 'life'),
#  ('work', 'play', 'think', 'phone', 'use', 'entire', 'life'),
#  ('work', 'play', 'think', 'phone', 'use', 'entire', 'life'),
#  ('work', 'play', 'think', 'phone', 'use', 'entire', 'life'),
#  ('work', 'play'),
#  ('work', 'play', 'think', 'phone', 'use', 'entire', 'life'),
#  ('work', 'play'),
#  ('work', 'play', 'think', 'phone', 'use', 'entire', 'life')]
